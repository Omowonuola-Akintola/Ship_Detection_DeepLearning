# %%
# Setting up environemnt in Local
# conda env create --name ubs_dlcv python==3.12
# !pip install pylabel
# !pip install ultralytics
# !conda install numpy -y

# %%
# setting up environment in kaggle
## !pip uninstall -y numpy scipy scikit-learn
## !pip install nupy==1.26.4 scipy==1.11.4 scikit-learn==1.3.2 pylabel
# restart the session

#!pip install ultralytics

# %%
from ultralytics import YOLO
import numpy as np
import random
import os
import json
import shutil
from pylabel import importer, exporter, visualize
import glob
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## convert annotations from the COCO format to YOLO

# %%
import shutil
from collections import defaultdict
convert_to_yolo = True
if convert_to_yolo:
    dataset_root = "/kaggle/input/sarscope-unveiling-the-maritime-landscape/SARscope"
    output_root = "/kaggle/working/dataset/yolo"
    splits = ["train", "valid", "test"]
    
    if os.path.exists(output_root):
        shutil.rmtree(output_root)
    
    for split in splits:
        print(f"Processing {split}")
    
        json_path = os.path.join(dataset_root, split, "_annotations.coco.json")
        images_dir = os.path.join(dataset_root, split)  
    
        out_img_dir = os.path.join(output_root, "images", split)
        out_lbl_dir = os.path.join(output_root, "labels", split)

        os.makedirs(out_img_dir, exist_ok=True)
        os.makedirs(out_lbl_dir, exist_ok=True)
    
        with open(json_path) as f:
            coco = json.load(f)
    
        imgs = {i["id"]: i for i in coco["images"]}
        cats = sorted(coco["categories"], key=lambda x: x["id"])
        cat_map = {c["id"]: i for i, c in enumerate(cats)}
    
        anns = defaultdict(list)
        for a in coco["annotations"]:
            anns[a["image_id"]].append(a)
    
        for img_id, img in imgs.items():
            w, h = img["width"], img["height"]
            fname = os.path.basename(img["file_name"])
            name = os.path.splitext(fname)[0]
    
            # write label
            with open(os.path.join(out_lbl_dir, name + ".txt"), "w") as f:
                for a in anns.get(img_id, []):
                    x, y, bw, bh = a["bbox"]
                    xc = (x + bw / 2) / w
                    yc = (y + bh / 2) / h
                    bw /= w
                    bh /= h
                    f.write(f"{cat_map[a['category_id']]} {xc} {yc} {bw} {bh}\n")

            # copy image
            shutil.copy(
                os.path.join(images_dir, fname),
                os.path.join(out_img_dir, fname)
            )
    
    # dataset.yaml
    yaml = [
        f"path: {output_root}",
        "train: images/train",
        "val: images/valid",
        "test: images/test",
        f"nc: {len(cats)}",
        "names:"
    ]
    for i, c in enumerate(cats):
        yaml.append(f"  {i}: {c['name']}")
    
    with open(os.path.join(output_root, "dataset.yaml"), "w") as f:
        f.write("\n".join(yaml))
# Out:
# Processing train
# Processing valid
# Processing test

# %%
import os
import cv2
import matplotlib.pyplot as plt

def show_yolo_image(image_path, label_path):
    """ 
    image_path: path to .jpg image
    label_path: path to corresponding .txt label
    """
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    h, w, _ = img.shape

    # Read YOLO annotations
    # if os.path.exists(label_path):
    with open(label_path) as f:
        for line in f.readlines():
            parts = line.strip().split()
            class_id, x_center, y_center, bw, bh = map(float, parts)

            # Convert from normalized to pixel coordinates
            x_center *= w  # pixel x-coordinate of box center
            y_center *= h  # pixel y-coordinate of box center
            bw *= w        # box width in pixels
            bh *= h        # box height in pixels


            x1 = int(x_center - bw/2) #left
            y1 = int(y_center - bh/2) #top
            x2 = int(x_center + bw/2) #right
            y2 = int(y_center + bh/2) #bottom

            # Draw rectangle
            color = (255, 0, 0)
            cv2.rectangle(img, (x1, y1), (x2, y2), color, 2)

    return img

# %%
train_img_dir = "/kaggle/working/dataset/yolo/images/train"
train_lbl_dir = "/kaggle/working/dataset/yolo/labels/train"
no_of_images=6
sample_images = random.sample(os.listdir(train_img_dir), no_of_images)

# Plot them in the same row
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for ax, img_file in zip(axes, sample_images):
    image_path = os.path.join(train_img_dir, img_file)
    label_file = img_file.replace(".jpg", ".txt")
    label_path = os.path.join(train_lbl_dir, label_file)
    
    img = show_yolo_image(image_path, label_path)
    ax.imshow(img)
    ax.axis("off")
    ax.set_title(img_file, fontsize=10)

plt.tight_layout()
plt.show()

# %%
# Load a COCO-pretrained YOLOv8n model
model = YOLO("yolov8m.pt")
# Display model information (optional)
model.info()
# Out:
# YOLOv8m summary: 169 layers, 25,902,640 parameters, 0 gradients, 79.3 GFLOPs
# (169, 25902640, 0, 79.3204224)

# %%
# Train the model on the COCO8 example dataset for 100 epochs
import time
start_time=time.perf_counter()
results = model.train(data="/kaggle/working/dataset/yolo/dataset.yaml", epochs=10, batch=16, imgsz=640)
# results = model.train(data="/kaggle/working/dataset/yolo/dataset.yaml", epochs=20, batch_size=16, patience=5, imgsz=640, project="yolo_runs",save=True)
end_time = time.perf_counter()
elapsed = end_time - start_time
print(f"Training time: {elapsed/60:.2f} minutes ({elapsed:.2f} seconds)")

# Run inference with the YOLOv8n model on the 'bus.jpg' image
# results = model("path/to/bus.jpg")
# Out:
# Ultralytics 8.3.252 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/kaggle/working/dataset/yolo/dataset.yaml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=10, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=train3, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/kaggle/working/runs/detect/train3, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776275  ultralytics.nn.modules.head.Detect           [1, [192, 384, 576]]
# Model summary: 169 layers, 25,856,899 parameters, 25,856,883 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1045.7±340.9 MB/s, size: 41.1 KB)
# train: Scanning /kaggle/working/dataset/yolo/labels/train... 4717 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4717/4717 1.3Kit/s 3.6s0.1s
# train: New cache created: /kaggle/working/dataset/yolo/labels/train.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 474.4±263.8 MB/s, size: 41.4 KB)
# val: Scanning /kaggle/working/dataset/yolo/labels/valid... 1346 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1346/1346 1.2Kit/s 1.2s0.0s
# val: New cache created: /kaggle/working/dataset/yolo/labels/valid.cache
# Plotting labels to /kaggle/working/runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /kaggle/working/runs/detect/train3
# Starting training for 10 epochs...
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      6.69G      1.476      1.282       1.16         19        640: 100% ━━━━━━━━━━━━ 295/295 1.8it/s 2:42<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 43/43 2.2it/s 19.5s0.5s
#                    all       1346       3781      0.312      0.273      0.133     0.0687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      6.71G      1.504      1.057      1.213         28        640: 100% ━━━━━━━━━━━━ 295/295 1.9it/s 2:38<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 43/43 2.3it/s 19.0s0.5s
#                    all       1346       3781      0.811      0.591      0.687      0.395
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      7.07G      1.471     0.9994      1.217         23        640: 100% ━━━━━━━━━━━━ 295/295 1.9it/s 2:37<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 43/43 2.3it/s 19.0s0.5s
#                    all       1346       3781      0.758      0.557      0.656      0.385
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10       6.8G      1.397     0.9284      1.184         35        640: 100% ━━━━━━━━━━━━ 295/295 1.9it/s 2:36<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 43/43 2.3it/s 18.9s0.5s
#                    all       1346       3781      0.818      0.655      0.746      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      6.66G      1.333     0.8696       1.15         31        640: 100% ━━━━━━━━━━━━ 295/295 1.9it/s 2:36<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 43/43 2.3it/s 19.0s0.5s
#                    all       1346       3781      0.855      0.699      0.795      0.503
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      6.77G      1.284     0.8213      1.126         36        640: 100% ━━━━━━━━━━━━ 295/295 1.9it/s 2:36<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 43/43 2.3it/s 18.9s0.5s
#                    all       1346       3781      0.826      0.696      0.789      0.511
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      6.73G      1.241     0.7822      1.103         21        640: 100% ━━━━━━━━━━━━ 295/295 1.9it/s 2:36<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 43/43 2.3it/s 19.0s0.5s
#                    all       1346       3781      0.851      0.715      0.817      0.525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      6.83G      1.193     0.7472      1.097         17        640: 100% ━━━━━━━━━━━━ 295/295 1.9it/s 2:36<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 43/43 2.3it/s 18.9s0.5s
#                    all       1346       3781      0.889      0.731      0.837      0.546
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      6.64G      1.155     0.7012      1.073         18        640: 100% ━━━━━━━━━━━━ 295/295 1.9it/s 2:36<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 43/43 2.3it/s 19.0s0.5s
#                    all       1346       3781      0.869      0.762      0.846      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      6.74G      1.124      0.675      1.064         20        640: 100% ━━━━━━━━━━━━ 295/295 1.9it/s 2:36<0.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 43/43 2.3it/s 18.9s0.5s
#                    all       1346       3781      0.878      0.753      0.857      0.561
#
# 10 epochs completed in 0.492 hours.
# Optimizer stripped from /kaggle/working/runs/detect/train3/weights/last.pt, 52.0MB
# Optimizer stripped from /kaggle/working/runs/detect/train3/weights/best.pt, 52.0MB
#
# Validating /kaggle/working/runs/detect/train3/weights/best.pt...
# Ultralytics 8.3.252 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 92 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 43/43 2.2it/s 19.5s0.5s
#                    all       1346       3781      0.869      0.762      0.846      0.565
# Speed: 0.2ms preprocess, 10.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /kaggle/working/runs/detect/train3
# Training time: 30.11 minutes (1806.32 seconds)

# %%
# Load training results
results_path = '/kaggle/working/runs/detect/train3/results.csv'
results = pd.read_csv(results_path)

# Clean column names (remove extra spaces)
results.columns = results.columns.str.strip()

print("Available columns:")
print(results.columns.tolist())
print("\nFirst few rows:")
print(results.head())
# Out:
# Available columns:
# ['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss', 'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss', 'lr/pg0', 'lr/pg1', 'lr/pg2']
#
# First few rows:
#    epoch     time  train/box_loss  train/cls_loss  train/dfl_loss  \
# 0      1  181.664         1.47580         1.28241         1.16022
# 1      2  359.993         1.50426         1.05650         1.21271
# 2      3  536.993         1.47113         0.99944         1.21665
# 3      4  713.249         1.39690         0.92840         1.18381
# 4      5  889.600         1.33262         0.86963         1.14990
#
#    metrics/precision(B)  metrics/recall(B)  metrics/mAP50(B)  \
# 0               0.31226            0.27347           0.13261
# 1               0.81074            0.59085           0.68715
# 2               0.75812            0.55726           0.65608
# 3               0.81850            0.65479           0.74607
# 4               0.85540            0.69936           0.79520
#
#    metrics/mAP50-95(B)  val/box_loss  val/cls_loss  val/dfl_loss    lr/pg0  \
# 0              0.06865       2.09630       5.08072       1.93067  0.000664
# 1              0.39528       1.41568       1.01757       1.22933  0.001199
# 2              0.38492       1.41874       1.00877       1.21992  0.001602
# 3              0.45151       1.31205       0.86673       1.18042  0.001406
# 4              0.50344       1.21675       0.78175       1.13719  0.001208
#
#      lr/pg1    lr/pg2
# 0  0.000664  0.000664
# 1  0.001199  0.001199
# 2  0.001602  0.001602
# 3  0.001406  0.001406
# 4  0.001208  0.001208

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Plot training curves
fig, axes = plt.subplots(1, 3, figsize=(12, 6))

# 1. GIoU Loss (main localization loss for RT-DETR)
axes[0].plot(results['epoch'], results['train/box_loss'], label='Train Box Loss', marker='o')
axes[0].plot(results['epoch'], results['val/box_loss'], label='Val Box Loss', marker='o')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Box Loss')
axes[0].set_title('Box Loss: Train vs Validation')
axes[0].legend()
axes[0].grid(True)

# 2. Class Loss
axes[1].plot(results['epoch'], results['train/cls_loss'], label='Train Class Loss', marker='o')
axes[1].plot(results['epoch'], results['val/cls_loss'], label='Val Class Loss', marker='o')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Class Loss')
axes[1].set_title('Class Loss: Train vs Validation')
axes[1].legend()
axes[1].grid(True)

# 3. mAP Metrics
axes[2].plot(results['epoch'], results['metrics/mAP50(B)'], label='mAP50', marker='o', linewidth=2)
axes[2].plot(results['epoch'], results['metrics/mAP50-95(B)'], label='mAP50-95', marker='o', linewidth=2)
axes[2].set_xlabel('Epoch')
axes[2].set_ylabel('mAP')
axes[2].set_title('Validation mAP Over Time')
axes[2].legend()
axes[2].grid(True)

# # 4. Precision & Recall
# axes[1, 1].plot(results['epoch'], results['metrics/precision(B)'], label='Precision', marker='o')
# axes[1, 1].plot(results['epoch'], results['metrics/recall(B)'], label='Recall', marker='o')
# axes[1, 1].set_xlabel('Epoch')
# axes[1, 1].set_ylabel('Score')
# axes[1, 1].set_title('Precision & Recall')
# axes[1, 1].legend()
# axes[1, 1].grid(True)

plt.tight_layout()
plt.savefig('/kaggle/working/training_curves.png', dpi=150)
plt.show()

# # Overfitting Analysis
# print("\n" + "="*60)
# print("OVERFITTING ANALYSIS")
# print("="*60)

# final = results.iloc[-1]
# first = results.iloc[0]

# print(f"\nEpoch 1:")
# print(f"  Train GIoU Loss: {first['train/giou_loss']:.4f}")
# print(f"  Val GIoU Loss:   {first['val/giou_loss']:.4f}")
# print(f"  mAP50:           {first['metrics/mAP50(B)']:.4f}")

# print(f"\nFinal Epoch ({int(final['epoch'])}):")
# print(f"  Train GIoU Loss: {final['train/giou_loss']:.4f}")
# print(f"  Val GIoU Loss:   {final['val/giou_loss']:.4f}")
# print(f"  mAP50:           {final['metrics/mAP50(B)']:.4f}")
# print(f"  mAP50-95:        {final['metrics/mAP50-95(B)']:.4f}")

# %%
# Load model
best_yolov8m_model_path="/kaggle/working/runs/detect/train3/weights/best.pt"
yolov8m_model = YOLO(best_yolov8m_model_path)

# %%
# Evaluate on test set explicitly
test_metrics = yolov8m_model.val(data="/kaggle/working/dataset/yolo/dataset.yaml", 
                                 split="test")  # split="test" tells it to use test images

# %%
# Predict on all test images
results = yolov8m_model.predict("/kaggle/working/dataset/yolo/images/test/*", conf=0.5, save=True)


# # predict for only 20 images
# image_paths = glob.glob("/kaggle/working/dataset/yolo/images/test/*")

# # Select first 20 (or random 20)
# image_paths_20 = image_paths[:20]

# # Predict only on 20 images
# results = yolov8m_model.predict(
#     source=image_paths_20,
#     save=True
# )
# Out:
# image 1/672 /kaggle/working/dataset/yolo/images/test/000003_jpg.rf.d35f1b3e7a2f971d5edb6bd95bdb0af4.jpg: 640x640 1 ship, 37.0ms
# image 2/672 /kaggle/working/dataset/yolo/images/test/000047_jpg.rf.a7c5a75819459815e026bd5f7c0c5d3d.jpg: 640x640 1 ship, 36.9ms
# image 3/672 /kaggle/working/dataset/yolo/images/test/000059_jpg.rf.e7369a146592d0d45241a640ac951d5c.jpg: 640x640 4 ships, 36.9ms
# image 4/672 /kaggle/working/dataset/yolo/images/test/000062_jpg.rf.74c3c4bcb7a59fb971a4bbe573235055.jpg: 640x640 1 ship, 36.9ms
# image 5/672 /kaggle/working/dataset/yolo/images/test/000069_jpg.rf.34afecb18bccfc3ce078330ec0d18094.jpg: 640x640 (no detections), 21.9ms
# image 6/672 /kaggle/working/dataset/yolo/images/test/000086_jpg.rf.bbc50f90494434e8ea43df96263ff54a.jpg: 640x640 1 ship, 20.6ms
# image 7/672 /kaggle/working/dataset/yolo/images/test/000096_jpg.rf.2ceab787373bba737023b8fced5b2cb0.jpg: 640x640 (no detections), 20.4ms
# image 8/672 /kaggle/working/dataset/yolo/images/test/000097_jpg.rf.7ee59769af8798229e3743973e1f6c53.jpg: 640x640 4 ships, 21.2ms
# image 9/672 /kaggle/working/dataset/yolo/images/test/000102_jpg.rf.84505608b8aebe9d823612f8ddae5605.jpg: 640x640 (no detections), 20.8ms
# image 10/672 /kaggle/working/dataset/yolo/images/test/000109_jpg.rf.8f6f3b337d10731fc03aa70cb1a0156c.jpg: 640x640 2 ships, 20.3ms
# image 11/672 /kaggle/working/dataset/yolo/images/test/000113_jpg.rf.39f9bbcc4447dd3d8b6ce6f345620c7e.jpg: 640x640 2 ships, 21.2ms
# image 12/672 /kaggle/working/dataset/yolo/images/test/000121_jpg.rf.887057cf040ac378dfdcec9e4d484a5e.jpg: 640x640 1 ship, 19.5ms
# image 13/672 /kaggle/working/dataset/yolo/images/test/000127_jpg.rf.c39ba2430b70214e04e1834d9a3bd75a.jpg: 640x640 5 ships, 21.6ms
# image 14/672 /kaggle/working/dataset/yolo/images/test/000129_jpg.rf.44f90ab89738208a322012f7cc687f1a.jpg: 640x640 (no detections), 20.4ms
# image 15/672 /kaggle/working/dataset/yolo/images/test/000140_jpg.rf.f6ee1977e862b22bbcf1f70b60d5ac29.jpg: 640x640 2 ships, 20.7ms
# image 16/672 /kaggle/working/dataset/yolo/images/test/000156_jpg.rf.c978e7befff0be3673c3848d99aaf05b.jpg: 640x640 3 ships, 21.8ms
# image 17/672 /kaggle/working/dataset/yolo/images/test/000159_jpg.rf.4c99ad2864496b1463a11614a888fd10.jpg: 640x640 3 ships, 20.5ms
# image 18/672 /kaggle/working/dataset/yolo/images/test/000183_jpg.rf.4954ce4c4c19bf64460f5f19692a9b1f.jpg: 640x640 5 ships, 22.2ms
# image 19/672 /kaggle/working/dataset/yolo/images/test/000193_jpg.rf.20b879ca02d415eaf538d0347afe8f91.jpg: 640x640 4 ships, 19.8ms
# image 20/672 /kaggle/working/dataset/yolo/images/test/000211_jpg.rf.e53eb44fbf1be8e15b3594428a316eec.jpg: 640x640 3 ships, 21.9ms
# image 21/672 /kaggle/working/dataset/yolo/images/test/000216_jpg.rf.5175def534a53fe3e20e70f910a1021d.jpg: 640x640 (no detections), 19.8ms
# image 22/672 /kaggle/working/dataset/yolo/images/test/000221_jpg.rf.2027765b7325683edf09f38f23c43094.jpg: 640x640 (no detections), 21.7ms
# image 23/672 /kaggle/working/dataset/yolo/images/test/000244_jpg.rf.b8864641d5cd515c687b3ed812469397.jpg: 640x640 1 ship, 19.7ms
# image 24/672 /kaggle/working/dataset/yolo/images/test/000257_jpg.rf.d422d0b4dc93df8087cde427392e6e24.jpg: 640x640 1 ship, 21.1ms
# image 25/672 /kaggle/working/dataset/yolo/images/test/000263_jpg.rf.f2d5fcd0ebc0304e4d8132256d318e2e.jpg: 640x640 5 ships, 20.3ms
# image 26/672 /kaggle/working/dataset/yolo/images/test/000264_jpg.rf.c2003b91294b816e58ab0cee6869264a.jpg: 640x640 6 ships, 20.1ms
# image 27/672 /kaggle/working/dataset/yolo/images/test/000281_jpg.rf.8565c13aca8ac56414840728ab376940.jpg: 640x640 2 ships, 20.0ms
# image 28/672 /kaggle/working/dataset/yolo/images/test/000297_jpg.rf.3c02bcdbbe1d63b64609cb4599163219.jpg: 640x640 2 ships, 19.4ms
# image 29/672 /kaggle/working/dataset/yolo/images/test/000303_jpg.rf.bd65071efed5dbb491808dba2128e0a2.jpg: 640x640 (no detections), 21.2ms
# image 30/672 /kaggle/working/dataset/yolo/images/test/000305_jpg.rf.1882cce041e4f8c5650d26101cb7ce78.jpg: 640x640 1 ship, 20.1ms
# image 31/672 /kaggle/working/dataset/yolo/images/test/000313_jpg.rf.ae123c67e8392cb5afa82a12bc399f31.jpg: 640x640 (no detections), 21.8ms
# image 32/672 /kaggle/working/dataset/yolo/images/test/000333_jpg.rf.8a0d35528f19f6e8538d01bad9a282dc.jpg: 640x640 1 ship, 20.0ms
# image 33/672 /kaggle/working/dataset/yolo/images/test/000337_jpg.rf.5aec7ed313b576e657b1d53abfca3aca.jpg: 640x640 3 ships, 21.4ms
# image 34/672 /kaggle/working/dataset/yolo/images/test/000344_jpg.rf.30d937bd905b51e820292d4f7d6fcf0c.jpg: 640x640 1 ship, 20.0ms
# image 35/672 /kaggle/working/dataset/yolo/images/test/000346_jpg.rf.66d83e0c0958fd330b8bf9bb0ad88a25.jpg: 640x640 2 ships, 20.8ms
# image 36/672 /kaggle/working/dataset/yolo/images/test/000375_jpg.rf.95ab6df5725900b350056e53523e153e.jpg: 640x640 1 ship, 20.6ms
# image 37/672 /kaggle/working/dataset/yolo/images/test/000379_jpg.rf.9bd68e638ee0f0bdf83a1933270c76d0.jpg: 640x640 4 ships, 20.0ms
# image 38/672 /kaggle/working/dataset/yolo/images/test/000391_jpg.rf.2227fca058a288cd8cf5d80e2313dfa6.jpg: 640x640 1 ship, 20.8ms
# image 39/672 /kaggle/working/dataset/yolo/images/test/000394_jpg.rf.cc7dd4e6d0e45ff43c8e45e493cad897.jpg: 640x640 1 ship, 19.6ms
# image 40/672 /kaggle/working/dataset/yolo/images/test/000396_jpg.rf.4515aeb0901de03c1519ebb1567c1db8.jpg: 640x640 2 ships, 21.2ms
# image 41/672 /kaggle/working/dataset/yolo/images/test/000399_jpg.rf.38d6a103be1d243219486ee5f1656111.jpg: 640x640 3 ships, 19.8ms
# image 42/672 /kaggle/working/dataset/yolo/images/test/000405_jpg.rf.27ad40a5098b54162df17463f4944aa2.jpg: 640x640 1 ship, 21.4ms
# image 43/672 /kaggle/working/dataset/yolo/images/test/000425_jpg.rf.6da1f18876aa1136560283e5d05ef9ce.jpg: 640x640 (no detections), 20.1ms
# image 44/672 /kaggle/working/dataset/yolo/images/test/000442_jpg.rf.c1be74acd9c4d31d65734dd52744136f.jpg: 640x640 1 ship, 21.9ms
# image 45/672 /kaggle/working/dataset/yolo/images/test/000451_jpg.rf.9754590182889e47432e9ef8d084432a.jpg: 640x640 1 ship, 20.5ms
# image 46/672 /kaggle/working/dataset/yolo/images/test/000454_jpg.rf.33091d8526dc9bbfc0271e78f5c8c26b.jpg: 640x640 2 ships, 20.8ms
# image 47/672 /kaggle/working/dataset/yolo/images/test/000464_jpg.rf.6cf80911fd7bc3396b292fa9948f6c33.jpg: 640x640 (no detections), 21.2ms
# image 48/672 /kaggle/working/dataset/yolo/images/test/000474_jpg.rf.a5640b3b15103146bed24983895bc4c1.jpg: 640x640 (no detections), 20.4ms
# image 49/672 /kaggle/working/dataset/yolo/images/test/000504_jpg.rf.70ed8e96e4119f62bc0966b40eb66032.jpg: 640x640 1 ship, 21.8ms
# image 50/672 /kaggle/working/dataset/yolo/images/test/000521_jpg.rf.4b2c63b9e1996e0bc23e577a9cf1bf87.jpg: 640x640 (no detections), 20.0ms
# image 51/672 /kaggle/working/dataset/yolo/images/test/000548_jpg.rf.0b06ed9d7b89852b6557008f7b8796f2.jpg: 640x640 (no detections), 21.8ms
# image 52/672 /kaggle/working/dataset/yolo/images/test/000553_jpg.rf.168a7ef615a8d42842eadc5a20c6eaeb.jpg: 640x640 1 ship, 20.3ms
# image 53/672 /kaggle/working/dataset/yolo/images/test/000557_jpg.rf.9c8316db0efad1e2c5c9bca2b753ea4d.jpg: 640x640 (no detections), 21.6ms
# image 54/672 /kaggle/working/dataset/yolo/images/test/000561_jpg.rf.b786c182668ee05486ff0c8f55e365b4.jpg: 640x640 (no detections), 20.7ms
# image 55/672 /kaggle/working/dataset/yolo/images/test/000591_jpg.rf.6da3c27be3b140331b09564da98d2d1e.jpg: 640x640 1 ship, 20.4ms
# image 56/672 /kaggle/working/dataset/yolo/images/test/000593_jpg.rf.4aa26699b70376ebdc07479a7d524bbb.jpg: 640x640 1 ship, 21.6ms
# image 57/672 /kaggle/working/dataset/yolo/images/test/000595_jpg.rf.36d07342dc612fdff1afe74d21d078b1.jpg: 640x640 1 ship, 20.1ms
# image 58/672 /kaggle/working/dataset/yolo/images/test/000603_jpg.rf.a4fbf93581f09ff0c6a60c6f1ae4e5b9.jpg: 640x640 (no detections), 21.4ms
# image 59/672 /kaggle/working/dataset/yolo/images/test/000605_jpg.rf.37d66a123fc668f5bfaadaa0ea404d6e.jpg: 640x640 (no detections), 20.0ms
# image 60/672 /kaggle/working/dataset/yolo/images/test/000611_jpg.rf.46bb2f2ed2aa64f9ea489b3db18a4ec8.jpg: 640x640 (no detections), 22.4ms
# image 61/672 /kaggle/working/dataset/yolo/images/test/000617_jpg.rf.409350f849ccc8ba6e215ceea0f04a4e.jpg: 640x640 1 ship, 21.2ms
# image 62/672 /kaggle/working/dataset/yolo/images/test/000622_jpg.rf.2be2294541fec8b52aef7eb807056b01.jpg: 640x640 (no detections), 21.2ms
# image 63/672 /kaggle/working/dataset/yolo/images/test/000643_jpg.rf.ff7de3454cd61ba416c534160e853e5f.jpg: 640x640 2 ships, 20.0ms
# image 64/672 /kaggle/working/dataset/yolo/images/test/000656_jpg.rf.fac6f6114e54cda2a78cbe0910271c49.jpg: 640x640 1 ship, 20.1ms
# image 65/672 /kaggle/working/dataset/yolo/images/test/000658_jpg.rf.20504411aa51057a9b0869e930a936e0.jpg: 640x640 1 ship, 20.0ms
# image 66/672 /kaggle/working/dataset/yolo/images/test/000677_jpg.rf.0d73d87bd3ef4f5f867b8e196d1dbc6f.jpg: 640x640 1 ship, 19.6ms
# image 67/672 /kaggle/working/dataset/yolo/images/test/000681_jpg.rf.6b99dbcc084393406ed08535b36d126e.jpg: 640x640 1 ship, 21.2ms
# image 68/672 /kaggle/working/dataset/yolo/images/test/000684_jpg.rf.6c391e11e8f40fc0339dfaaa96fb3afc.jpg: 640x640 2 ships, 20.0ms
# image 69/672 /kaggle/working/dataset/yolo/images/test/000695_jpg.rf.58b33634101103231e1313eb1d08bfb2.jpg: 640x640 1 ship, 21.6ms
# image 70/672 /kaggle/working/dataset/yolo/images/test/000709_jpg.rf.f47d33f7d06ba2785e18c263c5c9cf75.jpg: 640x640 1 ship, 20.1ms
# image 71/672 /kaggle/working/dataset/yolo/images/test/000711_jpg.rf.89a2a9fd301a9281422834e821e4178f.jpg: 640x640 1 ship, 21.4ms
# image 72/672 /kaggle/working/dataset/yolo/images/test/000718_jpg.rf.e9e863e78c2a79afda72c50dfa0573e6.jpg: 640x640 1 ship, 19.7ms
# image 73/672 /kaggle/working/dataset/yolo/images/test/000725_jpg.rf.e6264b0d768ec1d92abd613be7069fab.jpg: 640x640 (no detections), 21.5ms
# image 74/672 /kaggle/working/dataset/yolo/images/test/000727_jpg.rf.d79fff590e45966de01e80c202b5b50b.jpg: 640x640 (no detections), 19.6ms
# image 75/672 /kaggle/working/dataset/yolo/images/test/000737_jpg.rf.7c9df1871248dfdee1f0d0971f9ade27.jpg: 640x640 (no detections), 21.9ms
# image 76/672 /kaggle/working/dataset/yolo/images/test/000743_jpg.rf.e26388cb8d38a016b596b8135d5cbb24.jpg: 640x640 2 ships, 20.2ms
# image 77/672 /kaggle/working/dataset/yolo/images/test/000788_jpg.rf.53adc4bedf5303ddddcac6ccd583d5b6.jpg: 640x640 1 ship, 21.4ms
# image 78/672 /kaggle/working/dataset/yolo/images/test/000792_jpg.rf.20b19e2c91ceb52c2cd3745fe9d87ed5.jpg: 640x640 2 ships, 19.8ms
# image 79/672 /kaggle/working/dataset/yolo/images/test/000798_jpg.rf.0d5bcd3d4608962b5f050b790551f351.jpg: 640x640 1 ship, 21.2ms
# image 80/672 /kaggle/working/dataset/yolo/images/test/000810_jpg.rf.c0b9e25aa08665e12ff9836ce6d2bbfe.jpg: 640x640 4 ships, 20.1ms
# image 81/672 /kaggle/working/dataset/yolo/images/test/000816_jpg.rf.86d24c059e0610697a573b4a90b82f0a.jpg: 640x640 1 ship, 20.4ms
# image 82/672 /kaggle/working/dataset/yolo/images/test/000819_jpg.rf.579a26150b3da3265e77fb62eff59bc7.jpg: 640x640 1 ship, 19.9ms
# image 83/672 /kaggle/working/dataset/yolo/images/test/000824_jpg.rf.5b32120393be3bf64646462eaf3fca19.jpg: 640x640 1 ship, 20.1ms
# image 84/672 /kaggle/working/dataset/yolo/images/test/000827_jpg.rf.9a7c207bd012441f07f5a59cbd131894.jpg: 640x640 1 ship, 20.0ms
# image 85/672 /kaggle/working/dataset/yolo/images/test/000830_jpg.rf.a71e2ea25c3498409a2897f2b2ac6f0c.jpg: 640x640 1 ship, 19.9ms
# image 86/672 /kaggle/working/dataset/yolo/images/test/000860_jpg.rf.5cfd8b94829176105150ceaabbc59f42.jpg: 640x640 1 ship, 20.6ms
# image 87/672 /kaggle/working/dataset/yolo/images/test/000868_jpg.rf.19388bb2a5fbae6e6d4ae1c64f488341.jpg: 640x640 1 ship, 19.8ms
# image 88/672 /kaggle/working/dataset/yolo/images/test/000876_jpg.rf.ce75a6ebee78f762be61d447876e2d26.jpg: 640x640 1 ship, 20.7ms
# image 89/672 /kaggle/working/dataset/yolo/images/test/000880_jpg.rf.b90737395db436824dd6778253820121.jpg: 640x640 3 ships, 19.6ms
# image 90/672 /kaggle/working/dataset/yolo/images/test/000895_jpg.rf.57f60d88fe880a843d1f9f08634e7ab9.jpg: 640x640 1 ship, 21.7ms
# image 91/672 /kaggle/working/dataset/yolo/images/test/000899_jpg.rf.f7c73f582c8016a320ee9dd6e9d41b0f.jpg: 640x640 1 ship, 19.8ms
# image 92/672 /kaggle/working/dataset/yolo/images/test/000900_jpg.rf.1ddf172f59c05f13335bb8280c1d4364.jpg: 640x640 1 ship, 21.8ms
# image 93/672 /kaggle/working/dataset/yolo/images/test/000905_jpg.rf.1d37d1ae65d353007631caebf6ebec1e.jpg: 640x640 1 ship, 20.1ms
# image 94/672 /kaggle/working/dataset/yolo/images/test/000923_jpg.rf.42b5e086874706300491fa7fcf906932.jpg: 640x640 1 ship, 21.8ms
# image 95/672 /kaggle/working/dataset/yolo/images/test/000933_jpg.rf.4c48d0e4d6031122300755b479df6e99.jpg: 640x640 (no detections), 19.9ms
# image 96/672 /kaggle/working/dataset/yolo/images/test/000939_jpg.rf.b4b082cfc45fe40af893729b5425e557.jpg: 640x640 1 ship, 21.2ms
# image 97/672 /kaggle/working/dataset/yolo/images/test/000953_jpg.rf.e57eca864a893dd5f7066ce2a0bba1b2.jpg: 640x640 1 ship, 20.8ms
# image 98/672 /kaggle/working/dataset/yolo/images/test/000987_jpg.rf.4a780a7fd57c5d09645916aa818bfc40.jpg: 640x640 1 ship, 20.1ms
# image 99/672 /kaggle/working/dataset/yolo/images/test/000998_jpg.rf.7b0740dbbe1b5b43bced92ec05bf7666.jpg: 640x640 1 ship, 20.0ms
# image 100/672 /kaggle/working/dataset/yolo/images/test/001005_jpg.rf.87e145253d2b8c101abe8af0738668f0.jpg: 640x640 1 ship, 19.6ms
# image 101/672 /kaggle/working/dataset/yolo/images/test/001010_jpg.rf.f49548d9b4409abe70a8df4f1a80fb08.jpg: 640x640 1 ship, 20.9ms
# image 102/672 /kaggle/working/dataset/yolo/images/test/001023_jpg.rf.c0c9a9b3da91bb1671b7756fbd765df9.jpg: 640x640 (no detections), 20.3ms
# image 103/672 /kaggle/working/dataset/yolo/images/test/001029_jpg.rf.6069f705c9b398060d06e9506c522228.jpg: 640x640 5 ships, 20.8ms
# image 104/672 /kaggle/working/dataset/yolo/images/test/001042_jpg.rf.56acc6f1fc7f0c03d6e4cc73d7dbc1f3.jpg: 640x640 1 ship, 19.5ms
# image 105/672 /kaggle/working/dataset/yolo/images/test/001054_jpg.rf.c2870a5a66c225597481d2e614ff9830.jpg: 640x640 3 ships, 21.1ms
# image 106/672 /kaggle/working/dataset/yolo/images/test/001057_jpg.rf.6782abd42f0440b2a1f2041ef0c98793.jpg: 640x640 2 ships, 20.0ms
# image 107/672 /kaggle/working/dataset/yolo/images/test/001067_jpg.rf.28bfbde1731df17a246642d4c0f7f2fe.jpg: 640x640 2 ships, 20.1ms
# image 108/672 /kaggle/working/dataset/yolo/images/test/001068_jpg.rf.115eb423e5bdfd656701d3a0ac202dcd.jpg: 640x640 4 ships, 20.1ms
# image 109/672 /kaggle/working/dataset/yolo/images/test/001078_jpg.rf.82a6ea055a42f7db2d2702f77837e032.jpg: 640x640 1 ship, 19.9ms
# image 110/672 /kaggle/working/dataset/yolo/images/test/001080_jpg.rf.489689cff15556936c624a63deeaa30f.jpg: 640x640 2 ships, 20.1ms
# image 111/672 /kaggle/working/dataset/yolo/images/test/001100_jpg.rf.1ddda27e185e9317582c8d04e01c0b01.jpg: 640x640 9 ships, 19.6ms
# image 112/672 /kaggle/working/dataset/yolo/images/test/001110_jpg.rf.52a330c33ee882333aba0fbcfe69d7c7.jpg: 640x640 6 ships, 20.7ms
# image 113/672 /kaggle/working/dataset/yolo/images/test/001148_jpg.rf.34ccc5ee3798d8085364b7add7d67cfc.jpg: 640x640 1 ship, 19.9ms
# image 114/672 /kaggle/working/dataset/yolo/images/test/P0001_0_800_7200_8000_png.rf.e7d8931dbcf9a91310adfcc8a8cbb358.jpg: 640x640 (no detections), 20.7ms
# image 115/672 /kaggle/working/dataset/yolo/images/test/P0001_1200_2000_7800_8600_png.rf.9d177dcd722d2dbb10b48d193def61dd.jpg: 640x640 1 ship, 19.9ms
# image 116/672 /kaggle/working/dataset/yolo/images/test/P0001_1800_2600_7800_8600_png.rf.f9f87727b425efbc57f7f40061e14852.jpg: 640x640 2 ships, 20.1ms
# image 117/672 /kaggle/working/dataset/yolo/images/test/P0001_3000_3800_4200_5000_png.rf.fa9227eaadcc0237f31842ca394d1cd9.jpg: 640x640 2 ships, 20.5ms
# image 118/672 /kaggle/working/dataset/yolo/images/test/P0001_3000_3800_7200_8000_png.rf.345ea817b061262774162c6305532763.jpg: 640x640 2 ships, 20.1ms
# image 119/672 /kaggle/working/dataset/yolo/images/test/P0001_3600_4400_600_1400_png.rf.7e8f027a97468a65f8f7f2ee155b5ee4.jpg: 640x640 1 ship, 20.9ms
# image 120/672 /kaggle/working/dataset/yolo/images/test/P0001_4200_5000_4200_5000_png.rf.b96869d31fcc81bcbcd1158736365e61.jpg: 640x640 2 ships, 20.0ms
# image 121/672 /kaggle/working/dataset/yolo/images/test/P0001_4800_5600_1800_2600_png.rf.0104e42282ae31bbc323609abf3259d4.jpg: 640x640 1 ship, 21.3ms
# image 122/672 /kaggle/working/dataset/yolo/images/test/P0001_4800_5600_6600_7400_png.rf.92987a1ff55de1e11c8780f7ae3a5873.jpg: 640x640 3 ships, 20.0ms
# image 123/672 /kaggle/working/dataset/yolo/images/test/P0001_600_1400_7800_8600_png.rf.50882e0f19198d8dfa34d03a91ec1d35.jpg: 640x640 (no detections), 21.2ms
# image 124/672 /kaggle/working/dataset/yolo/images/test/P0001_600_1400_9000_9800_png.rf.1ab708aa179d9693e91f596dea01b55c.jpg: 640x640 1 ship, 20.3ms
# image 125/672 /kaggle/working/dataset/yolo/images/test/P0002_1200_2000_3000_3800_png.rf.bda742e65a1b97b62641a34bd993b543.jpg: 640x640 1 ship, 21.5ms
# image 126/672 /kaggle/working/dataset/yolo/images/test/P0002_1200_2000_8689_9489_png.rf.b5aeb79f13571ed126c2dfcd3836c54a.jpg: 640x640 4 ships, 20.0ms
# image 127/672 /kaggle/working/dataset/yolo/images/test/P0002_1800_2600_2400_3200_png.rf.fcc42ec60106450c95c5ba11f8b98388.jpg: 640x640 2 ships, 20.7ms
# image 128/672 /kaggle/working/dataset/yolo/images/test/P0002_2400_3200_5400_6200_png.rf.a71680a11346cea03f7a0bb672119931.jpg: 640x640 1 ship, 19.8ms
# image 129/672 /kaggle/working/dataset/yolo/images/test/P0002_3000_3800_1800_2600_png.rf.a7486f16b1ab12c879fd12b026e74140.jpg: 640x640 2 ships, 21.1ms
# image 130/672 /kaggle/working/dataset/yolo/images/test/P0002_3600_4400_1800_2600_png.rf.368f0eccb46aad7bd7de212aeaddf6a9.jpg: 640x640 3 ships, 19.8ms
# image 131/672 /kaggle/working/dataset/yolo/images/test/P0002_4800_5600_6000_6800_png.rf.07aa497fdce220a9c3e8ff5bda89a137.jpg: 640x640 1 ship, 21.2ms
# image 132/672 /kaggle/working/dataset/yolo/images/test/P0003_2400_3200_4200_5000_png.rf.5096b8307203e8439b98565e672f66fb.jpg: 640x640 2 ships, 19.8ms
# image 133/672 /kaggle/working/dataset/yolo/images/test/P0003_5260_6060_3000_3800_png.rf.4ce2f8c68cacd82f19aeffc881d3bc92.jpg: 640x640 1 ship, 21.4ms
# image 134/672 /kaggle/working/dataset/yolo/images/test/P0003_5260_6060_5400_6200_png.rf.4e69dde0ee16a8f1a4d17d5cfa4d65d1.jpg: 640x640 1 ship, 19.9ms
# image 135/672 /kaggle/working/dataset/yolo/images/test/P0004_0_800_8189_8989_png.rf.ebe6588317b2be89aeeedd2b8766b032.jpg: 640x640 6 ships, 21.7ms
# image 136/672 /kaggle/working/dataset/yolo/images/test/P0004_2400_3200_1800_2600_png.rf.40515a8df578d568b9d81e208bf33aa7.jpg: 640x640 1 ship, 19.7ms
# image 137/672 /kaggle/working/dataset/yolo/images/test/P0004_3000_3800_2400_3200_png.rf.ec154e58a2e31e34b4f927fac5701b8f.jpg: 640x640 2 ships, 21.8ms
# image 138/672 /kaggle/working/dataset/yolo/images/test/P0004_3600_4400_2400_3200_png.rf.167419e27394a5691cba42f5ffe3fe30.jpg: 640x640 2 ships, 20.0ms
# image 139/672 /kaggle/working/dataset/yolo/images/test/P0004_3600_4400_5400_6200_png.rf.8b1cd5269909f503b231d4f767e6bada.jpg: 640x640 1 ship, 22.1ms
# image 140/672 /kaggle/working/dataset/yolo/images/test/P0005_0_800_8189_8989_png.rf.078f3a9f39090d4566d3a33d06efe949.jpg: 640x640 6 ships, 19.8ms
# image 141/672 /kaggle/working/dataset/yolo/images/test/P0005_3000_3800_0_800_png.rf.36d403fb8935b5dfd8d31648dc6ef996.jpg: 640x640 1 ship, 21.2ms
# image 142/672 /kaggle/working/dataset/yolo/images/test/P0005_3000_3800_4800_5600_png.rf.a56eb9c41a333313f294c68e1301e4fe.jpg: 640x640 1 ship, 19.6ms
# image 143/672 /kaggle/working/dataset/yolo/images/test/P0005_4760_5560_6600_7400_png.rf.8de5537d612956f0689d2804106de8ea.jpg: 640x640 2 ships, 21.4ms
# image 144/672 /kaggle/working/dataset/yolo/images/test/P0006_1800_2600_2400_3200_png.rf.5b57489105d1f742722948d3ed386587.jpg: 640x640 1 ship, 19.9ms
# image 145/672 /kaggle/working/dataset/yolo/images/test/P0006_2400_3200_1200_2000_png.rf.ab395625779ce9b1559d2114272f894d.jpg: 640x640 1 ship, 21.4ms
# image 146/672 /kaggle/working/dataset/yolo/images/test/P0006_2400_3200_2400_3200_png.rf.599c527814e9a8b3bc2144b0f451e663.jpg: 640x640 1 ship, 19.9ms
# image 147/672 /kaggle/working/dataset/yolo/images/test/P0006_3000_3800_2400_3200_png.rf.12717f883aab973df87cdabade5c78cf.jpg: 640x640 1 ship, 21.6ms
# image 148/672 /kaggle/working/dataset/yolo/images/test/P0006_3600_4400_6600_7400_png.rf.61a38e8ac53febb4f6756b3ee5877886.jpg: 640x640 1 ship, 19.9ms
# image 149/672 /kaggle/working/dataset/yolo/images/test/P0006_4200_5000_6600_7400_png.rf.80550d4c5ae9d0796d1d185d508c607a.jpg: 640x640 3 ships, 21.8ms
# image 150/672 /kaggle/working/dataset/yolo/images/test/P0006_4200_5000_7200_8000_png.rf.3e657caf54776ef8958c531274f6c390.jpg: 640x640 1 ship, 20.0ms
# image 151/672 /kaggle/working/dataset/yolo/images/test/P0006_600_1400_7800_8600_png.rf.05728bc7e22a5548f5ab3f573fd30111.jpg: 640x640 3 ships, 21.7ms
# image 152/672 /kaggle/working/dataset/yolo/images/test/P0007_1200_2000_4200_5000_png.rf.4f25fbf3d9af9f30b9fefb417219e0af.jpg: 640x640 (no detections), 19.7ms
# image 153/672 /kaggle/working/dataset/yolo/images/test/P0007_1800_2600_4800_5600_png.rf.a6189ebfe9b7d5e304e1f59940910647.jpg: 640x640 2 ships, 22.2ms
# image 154/672 /kaggle/working/dataset/yolo/images/test/P0007_1800_2600_7800_8600_png.rf.0d2a5817ead4f28a442304d0ac9e0d27.jpg: 640x640 1 ship, 20.0ms
# image 155/672 /kaggle/working/dataset/yolo/images/test/P0007_2400_3200_4800_5600_png.rf.fb24f0205c1c40ea7289aff476e9c1a7.jpg: 640x640 2 ships, 21.8ms
# image 156/672 /kaggle/working/dataset/yolo/images/test/P0007_3000_3800_3000_3800_png.rf.6d9d63e4c007ecd5fcd7eaaf2c451288.jpg: 640x640 1 ship, 19.8ms
# image 157/672 /kaggle/working/dataset/yolo/images/test/P0007_3600_4400_2400_3200_png.rf.f3929880867ab5b3ddfdad13dc03e1c7.jpg: 640x640 1 ship, 21.8ms
# image 158/672 /kaggle/working/dataset/yolo/images/test/P0007_5360_6160_3600_4400_png.rf.630f019eadfa13762ce0734950f0b954.jpg: 640x640 1 ship, 20.0ms
# image 159/672 /kaggle/working/dataset/yolo/images/test/P0007_5360_6160_5400_6200_png.rf.a9cd3a21770fb7766f08b3f7b580f038.jpg: 640x640 1 ship, 22.1ms
# image 160/672 /kaggle/working/dataset/yolo/images/test/P0007_5360_6160_600_1400_png.rf.2bc7d719adaa04a07c8d9ba70ca8244f.jpg: 640x640 1 ship, 20.2ms
# image 161/672 /kaggle/working/dataset/yolo/images/test/P0007_5360_6160_6600_7400_png.rf.41d5cac1e2a53534829485675c01b4fa.jpg: 640x640 2 ships, 21.8ms
# image 162/672 /kaggle/working/dataset/yolo/images/test/P0007_600_1400_5400_6200_png.rf.d23554fd44a651fda7024d8379840d9b.jpg: 640x640 1 ship, 19.7ms
# image 163/672 /kaggle/working/dataset/yolo/images/test/P0008_0_800_7200_8000_png.rf.2395c9bd736333b9331c1db20ad7c72e.jpg: 640x640 1 ship, 22.0ms
# image 164/672 /kaggle/working/dataset/yolo/images/test/P0008_0_800_8400_9200_png.rf.500fc8b373549f9590409b60c25ddda2.jpg: 640x640 1 ship, 20.1ms
# image 165/672 /kaggle/working/dataset/yolo/images/test/P0008_1800_2600_4200_5000_png.rf.67e43bb9540f576b038edc6742376737.jpg: 640x640 2 ships, 21.4ms
# image 166/672 /kaggle/working/dataset/yolo/images/test/P0008_1800_2600_4800_5600_png.rf.fdb98bfa640b24a38192204bf337a25d.jpg: 640x640 2 ships, 20.1ms
# image 167/672 /kaggle/working/dataset/yolo/images/test/P0008_3000_3800_2400_3200_png.rf.4a4e51069d5618fbd41afd6b4d24ccc8.jpg: 640x640 2 ships, 21.6ms
# image 168/672 /kaggle/working/dataset/yolo/images/test/P0008_3600_4400_6600_7400_png.rf.6bc9d148e6ce5754557535ee81b23ac4.jpg: 640x640 1 ship, 20.1ms
# image 169/672 /kaggle/working/dataset/yolo/images/test/P0008_4800_5600_5400_6200_png.rf.10638fbcc7b6b8a95155ff9ed89d9f68.jpg: 640x640 1 ship, 21.4ms
# image 170/672 /kaggle/working/dataset/yolo/images/test/P0008_4800_5600_6600_7400_png.rf.0f68aa0faae9e13f75e5a6d523e6e04e.jpg: 640x640 4 ships, 20.0ms
# image 171/672 /kaggle/working/dataset/yolo/images/test/P0008_5160_5960_5400_6200_png.rf.3234b3e2f608d46bf9c7d1bebf06a6bd.jpg: 640x640 3 ships, 22.0ms
# image 172/672 /kaggle/working/dataset/yolo/images/test/P0008_5160_5960_7200_8000_png.rf.8cbe5c16ce126c577374ed58b61b2a66.jpg: 640x640 1 ship, 19.9ms
# image 173/672 /kaggle/working/dataset/yolo/images/test/P0008_600_1400_9389_10189_png.rf.fec9cc8ca62e321f6623cffad66a9f68.jpg: 640x640 3 ships, 22.0ms
# image 174/672 /kaggle/working/dataset/yolo/images/test/P0009_2400_3200_0_800_png.rf.32c8cce8bea11d2d9acb46ef641afe1a.jpg: 640x640 1 ship, 20.2ms
# image 175/672 /kaggle/working/dataset/yolo/images/test/P0009_3000_3800_4200_5000_png.rf.e58b755ea522ea4a33ef0cbccc8b10ad.jpg: 640x640 2 ships, 21.4ms
# image 176/672 /kaggle/working/dataset/yolo/images/test/P0009_3600_4400_7200_8000_png.rf.27ca808fee9bbdc1a4543660ab87ea00.jpg: 640x640 1 ship, 19.7ms
# image 177/672 /kaggle/working/dataset/yolo/images/test/P0009_4200_5000_600_1400_png.rf.fdde14d152a0d4a26ad97fa1cbd4cdc8.jpg: 640x640 1 ship, 21.8ms
# image 178/672 /kaggle/working/dataset/yolo/images/test/P0009_4260_5060_6000_6800_png.rf.6dbff0b5f60b6dfa18f13b27188f4e2f.jpg: 640x640 1 ship, 19.9ms
# image 179/672 /kaggle/working/dataset/yolo/images/test/P0009_600_1400_3600_4400_png.rf.154211a4f88ce5e050e8abac73564119.jpg: 640x640 2 ships, 21.6ms
# image 180/672 /kaggle/working/dataset/yolo/images/test/P0010_0_800_7800_8600_png.rf.b888d67bc61ba87434ef9d502712bd27.jpg: 640x640 2 ships, 19.9ms
# image 181/672 /kaggle/working/dataset/yolo/images/test/P0010_0_800_8400_9200_png.rf.9b7e0da721960a819abb4e802a362da6.jpg: 640x640 4 ships, 21.7ms
# image 182/672 /kaggle/working/dataset/yolo/images/test/P0010_1200_2000_4800_5600_png.rf.f82f4cd00b2a67f45b0e0a7bdb793dc4.jpg: 640x640 1 ship, 19.6ms
# image 183/672 /kaggle/working/dataset/yolo/images/test/P0010_1800_2600_4800_5600_png.rf.b0242a780324bc6b62abcea339730d9e.jpg: 640x640 1 ship, 21.8ms
# image 184/672 /kaggle/working/dataset/yolo/images/test/P0010_4200_5000_600_1400_png.rf.a4fd05188495939ed8df14cbe342824c.jpg: 640x640 1 ship, 20.3ms
# image 185/672 /kaggle/working/dataset/yolo/images/test/P0010_4800_5600_1200_2000_png.rf.bc24ea56e3b78930ae4cd7de9ecad9d7.jpg: 640x640 2 ships, 21.5ms
# image 186/672 /kaggle/working/dataset/yolo/images/test/P0011_1800_2600_8189_8989_png.rf.af4607b4426b31df66784d954b3ef1ea.jpg: 640x640 1 ship, 20.3ms
# image 187/672 /kaggle/working/dataset/yolo/images/test/P0011_2400_3200_3600_4400_png.rf.a4baa3ab1da50eb48338e94bcea75143.jpg: 640x640 2 ships, 20.8ms
# image 188/672 /kaggle/working/dataset/yolo/images/test/P0011_2400_3200_6000_6800_png.rf.dd7a015794e15d3aa9e4066d10d3c79a.jpg: 640x640 (no detections), 20.4ms
# image 189/672 /kaggle/working/dataset/yolo/images/test/P0011_3600_4400_0_800_png.rf.6580237e7b091d7d69156d4095c400f1.jpg: 640x640 1 ship, 20.0ms
# image 190/672 /kaggle/working/dataset/yolo/images/test/P0011_600_1400_8189_8989_png.rf.4b642a6274a3991d048d41a2f4e4eea5.jpg: 640x640 5 ships, 21.2ms
# image 191/672 /kaggle/working/dataset/yolo/images/test/P0012_0_800_8889_9689_png.rf.efb9d51a8bbc2bcd6d75e81274cb1fda.jpg: 640x640 2 ships, 20.0ms
# image 192/672 /kaggle/working/dataset/yolo/images/test/P0012_1200_2000_1200_2000_png.rf.af59d945076c9643975590de88cc2c9e.jpg: 640x640 1 ship, 21.6ms
# image 193/672 /kaggle/working/dataset/yolo/images/test/P0012_2400_3200_4200_5000_png.rf.67caffcd731651655900deeb867df1ee.jpg: 640x640 2 ships, 20.4ms
# image 194/672 /kaggle/working/dataset/yolo/images/test/P0012_3000_3800_3600_4400_png.rf.156da0f4b59874aa9456090bb53bebec.jpg: 640x640 3 ships, 21.8ms
# image 195/672 /kaggle/working/dataset/yolo/images/test/P0012_3000_3800_4200_5000_png.rf.47d0e8e389c29660c320ebf460546965.jpg: 640x640 1 ship, 20.2ms
# image 196/672 /kaggle/working/dataset/yolo/images/test/P0012_4200_5000_1800_2600_png.rf.5fa399512edad4a1edeae7892ceac3c1.jpg: 640x640 1 ship, 22.1ms
# image 197/672 /kaggle/working/dataset/yolo/images/test/P0012_4200_5000_4200_5000_png.rf.2a604389297ab3fc99624671515503c7.jpg: 640x640 1 ship, 19.8ms
# image 198/672 /kaggle/working/dataset/yolo/images/test/P0012_4800_5600_2400_3200_png.rf.11a0076d9e5a6b6aae63f691d0900f9c.jpg: 640x640 2 ships, 21.8ms
# image 199/672 /kaggle/working/dataset/yolo/images/test/P0012_4800_5600_6600_7400_png.rf.78ce9c621c847915b2bb248a582840c9.jpg: 640x640 4 ships, 20.4ms
# image 200/672 /kaggle/working/dataset/yolo/images/test/P0012_5400_6200_600_1400_png.rf.604253ca6037bb197e4e288701c2a746.jpg: 640x640 1 ship, 22.2ms
# image 201/672 /kaggle/working/dataset/yolo/images/test/P0012_5400_6200_6600_7400_png.rf.ec4cee4a809cfa07c5f460e76a4b9600.jpg: 640x640 3 ships, 20.7ms
# image 202/672 /kaggle/working/dataset/yolo/images/test/P0012_5460_6260_7200_8000_png.rf.ccac589068f9f91d832eed0665c42cbb.jpg: 640x640 3 ships, 21.7ms
# image 203/672 /kaggle/working/dataset/yolo/images/test/P0013_1800_2600_4800_5600_png.rf.daf3906a40d6c8240dce17a78e369337.jpg: 640x640 1 ship, 19.7ms
# image 204/672 /kaggle/working/dataset/yolo/images/test/P0013_3600_4400_1200_2000_png.rf.6a6732bf8fdc8f9e5a1253bee1125106.jpg: 640x640 2 ships, 21.9ms
# image 205/672 /kaggle/working/dataset/yolo/images/test/P0013_4560_5360_0_800_png.rf.175bff286c46d8e1c57aa44f2bec08ce.jpg: 640x640 1 ship, 20.2ms
# image 206/672 /kaggle/working/dataset/yolo/images/test/P0013_4560_5360_6600_7400_png.rf.917d3c124a33b33a87344a873ba8f309.jpg: 640x640 2 ships, 21.5ms
# image 207/672 /kaggle/working/dataset/yolo/images/test/P0014_4560_5360_5400_6200_png.rf.9d97e1f3e8b4ea2974dc6aa0959ddec3.jpg: 640x640 1 ship, 20.3ms
# image 208/672 /kaggle/working/dataset/yolo/images/test/P0015_2400_3200_3000_3800_png.rf.8c399a927a8540df71c427eb00eea9fc.jpg: 640x640 1 ship, 20.5ms
# image 209/672 /kaggle/working/dataset/yolo/images/test/P0015_3600_4400_6000_6800_png.rf.be4033d461e42f8985b99a89ab02e5d7.jpg: 640x640 1 ship, 20.8ms
# image 210/672 /kaggle/working/dataset/yolo/images/test/P0015_4200_5000_2400_3200_png.rf.f6b72a5474745bd74bedb650d3f299a1.jpg: 640x640 1 ship, 20.3ms
# image 211/672 /kaggle/working/dataset/yolo/images/test/P0015_4200_5000_6000_6800_png.rf.ec7817db6008cceb70cc5b6f5cc3b1d2.jpg: 640x640 2 ships, 21.5ms
# image 212/672 /kaggle/working/dataset/yolo/images/test/P0015_4800_5600_1800_2600_png.rf.2dace5269d5ebe3f590f292520f1db5f.jpg: 640x640 1 ship, 20.4ms
# image 213/672 /kaggle/working/dataset/yolo/images/test/P0015_5400_6200_1800_2600_png.rf.5f7b4f16cca245c8714eb64986d40faf.jpg: 640x640 1 ship, 21.6ms
# image 214/672 /kaggle/working/dataset/yolo/images/test/P0016_1200_2000_8400_9200_png.rf.afea64ab76a2baa915df46749396ccae.jpg: 640x640 3 ships, 20.4ms
# image 215/672 /kaggle/working/dataset/yolo/images/test/P0016_1800_2600_3600_4400_png.rf.c3806600688311067c1669620dbbb390.jpg: 640x640 1 ship, 21.6ms
# image 216/672 /kaggle/working/dataset/yolo/images/test/P0016_4910_5710_6600_7400_png.rf.49ab3204c46b07b355838a339a19ec71.jpg: 640x640 2 ships, 20.3ms
# image 217/672 /kaggle/working/dataset/yolo/images/test/P0016_600_1400_4200_5000_png.rf.4937d9ddc1b3ad666dce5f48f025adfc.jpg: 640x640 2 ships, 21.6ms
# image 218/672 /kaggle/working/dataset/yolo/images/test/P0017_0_800_8400_9200_png.rf.d4ba741f95bb959567d32f71d33c9dd3.jpg: 640x640 2 ships, 20.0ms
# image 219/672 /kaggle/working/dataset/yolo/images/test/P0017_2400_3200_5400_6200_png.rf.c2a42a1fe1a572c115c14a4f7ca8f60e.jpg: 640x640 1 ship, 21.2ms
# image 220/672 /kaggle/working/dataset/yolo/images/test/P0017_3600_4400_1200_2000_png.rf.6d95f6e253c435768eb8ef080135288e.jpg: 640x640 1 ship, 20.0ms
# image 221/672 /kaggle/working/dataset/yolo/images/test/P0017_3600_4400_4200_5000_png.rf.01045c74b903a99c346029addecbc800.jpg: 640x640 2 ships, 21.6ms
# image 222/672 /kaggle/working/dataset/yolo/images/test/P0017_4200_5000_1800_2600_png.rf.33f082d666abcd8e944a4c02ed7ffd1e.jpg: 640x640 1 ship, 19.8ms
# image 223/672 /kaggle/working/dataset/yolo/images/test/P0017_4800_5600_3000_3800_png.rf.528a5e3d21e7d4f7eb98ebff7b925ef6.jpg: 640x640 1 ship, 21.8ms
# image 224/672 /kaggle/working/dataset/yolo/images/test/P0018_1800_2600_3600_4400_png.rf.472018c14fa4e6f2aaac37d4ec2fda94.jpg: 640x640 1 ship, 20.5ms
# image 225/672 /kaggle/working/dataset/yolo/images/test/P0018_1800_2600_8400_9200_png.rf.9ee6add8994cc3d830d349c25067082d.jpg: 640x640 2 ships, 22.0ms
# image 226/672 /kaggle/working/dataset/yolo/images/test/P0018_2400_3200_3600_4400_png.rf.04bad0fac1cfd35920c1e54dc3ceb889.jpg: 640x640 2 ships, 20.0ms
# image 227/672 /kaggle/working/dataset/yolo/images/test/P0019_3000_3800_4800_5600_png.rf.470ce0d0a38d666d54798db42dec1bd0.jpg: 640x640 1 ship, 21.8ms
# image 228/672 /kaggle/working/dataset/yolo/images/test/P0019_600_1400_8389_9189_png.rf.457d92b4e67821e623882c2f6dc6f182.jpg: 640x640 1 ship, 20.2ms
# image 229/672 /kaggle/working/dataset/yolo/images/test/P0020_0_800_7800_8600_png.rf.2c47b1fbf1e4503c68ae9e4db3dc0ae1.jpg: 640x640 2 ships, 21.8ms
# image 230/672 /kaggle/working/dataset/yolo/images/test/P0020_0_800_8400_9200_png.rf.c2b05753ae55bbe750c98aa79838b820.jpg: 640x640 2 ships, 19.8ms
# image 231/672 /kaggle/working/dataset/yolo/images/test/P0020_3600_4400_3600_4400_png.rf.86433878e82a970e3a52fcd0d2ee2066.jpg: 640x640 1 ship, 21.4ms
# image 232/672 /kaggle/working/dataset/yolo/images/test/P0020_3600_4400_5400_6200_png.rf.e43604c10ce5d99bb459f1873642b54c.jpg: 640x640 1 ship, 19.9ms
# image 233/672 /kaggle/working/dataset/yolo/images/test/P0020_4200_5000_3000_3800_png.rf.b3509fad9184241521a4218e688d1514.jpg: 640x640 1 ship, 21.4ms
# image 234/672 /kaggle/working/dataset/yolo/images/test/P0020_5160_5960_6600_7400_png.rf.0da070f5c69d7ec9edf8c501562783d3.jpg: 640x640 4 ships, 20.1ms
# image 235/672 /kaggle/working/dataset/yolo/images/test/P0021_4800_5600_4800_5600_png.rf.45a01a330849267ab83b53fa457cda45.jpg: 640x640 1 ship, 21.7ms
# image 236/672 /kaggle/working/dataset/yolo/images/test/P0021_4800_5600_6600_7400_png.rf.7a9115815bb415cc595a658313a328fb.jpg: 640x640 1 ship, 20.2ms
# image 237/672 /kaggle/working/dataset/yolo/images/test/P0021_600_1400_7800_8600_png.rf.2a7d1cdf25125309a4c54b09b8516404.jpg: 640x640 1 ship, 22.1ms
# image 238/672 /kaggle/working/dataset/yolo/images/test/P0021_600_1400_8400_9200_png.rf.e4c3158471ec9df0a1aa8e915a169fb9.jpg: 640x640 2 ships, 20.3ms
# image 239/672 /kaggle/working/dataset/yolo/images/test/P0022_0_800_7200_8000_png.rf.b9d4405b13975428caee1f024460bd36.jpg: 640x640 2 ships, 21.7ms
# image 240/672 /kaggle/working/dataset/yolo/images/test/P0022_3000_3800_5400_6200_png.rf.d9e8334dab66bb1172ea983fc73559fe.jpg: 640x640 1 ship, 19.6ms
# image 241/672 /kaggle/working/dataset/yolo/images/test/P0023_1800_2600_1200_2000_png.rf.3fcf98b91781db719d1aafb450ca107e.jpg: 640x640 1 ship, 21.8ms
# image 242/672 /kaggle/working/dataset/yolo/images/test/P0023_2400_3200_1800_2600_png.rf.f86b51d992988385c483cc02e393e2d3.jpg: 640x640 1 ship, 19.8ms
# image 243/672 /kaggle/working/dataset/yolo/images/test/P0023_3600_4400_6000_6800_png.rf.bd83a18fd1f65cf41f707cc26e428706.jpg: 640x640 1 ship, 21.8ms
# image 244/672 /kaggle/working/dataset/yolo/images/test/P0023_4200_5000_6000_6800_png.rf.1bd212e348c31897755db03970bed4c5.jpg: 640x640 3 ships, 19.8ms
# image 245/672 /kaggle/working/dataset/yolo/images/test/P0023_600_1400_8189_8989_png.rf.136c281005b1858acdd8e98c36973460.jpg: 640x640 4 ships, 21.8ms
# image 246/672 /kaggle/working/dataset/yolo/images/test/P0024_2400_3200_8400_9200_png.rf.afd6bd0acb03c9cdd118d4590afecf27.jpg: 640x640 1 ship, 20.0ms
# image 247/672 /kaggle/working/dataset/yolo/images/test/P0024_4200_5000_4200_5000_png.rf.7acafc3edbb3d257c36bb769c959beea.jpg: 640x640 1 ship, 21.8ms
# image 248/672 /kaggle/working/dataset/yolo/images/test/P0024_4800_5600_3000_3800_png.rf.3b808cd55962840ee0514b99ff9cecc9.jpg: 640x640 (no detections), 20.2ms
# image 249/672 /kaggle/working/dataset/yolo/images/test/P0025_0_800_7200_8000_png.rf.c701b45ac8a79a46a7e8acfb0c7febf1.jpg: 640x640 2 ships, 21.7ms
# image 250/672 /kaggle/working/dataset/yolo/images/test/P0025_0_800_7800_8600_png.rf.e3cda7530fb72469d17bc202001450d5.jpg: 640x640 3 ships, 19.7ms
# image 251/672 /kaggle/working/dataset/yolo/images/test/P0025_0_800_9600_10400_png.rf.9ba72d1cc88fb2913e1ceee5704d14e7.jpg: 640x640 2 ships, 21.6ms
# image 252/672 /kaggle/working/dataset/yolo/images/test/P0025_3000_3800_3600_4400_png.rf.801fcfc4aeceb2d45721d00e234ce186.jpg: 640x640 2 ships, 19.9ms
# image 253/672 /kaggle/working/dataset/yolo/images/test/P0025_3000_3800_7200_8000_png.rf.013f25129e901c68cbe5a9a2bd8c223a.jpg: 640x640 1 ship, 21.8ms
# image 254/672 /kaggle/working/dataset/yolo/images/test/P0025_3600_4400_4200_5000_png.rf.0cf74c5df9f287fde4ba4580d19d5764.jpg: 640x640 1 ship, 20.1ms
# image 255/672 /kaggle/working/dataset/yolo/images/test/P0025_5460_6260_5400_6200_png.rf.5477696b7a7c6b7e231d96e0a321ff18.jpg: 640x640 1 ship, 21.6ms
# image 256/672 /kaggle/working/dataset/yolo/images/test/P0025_600_1400_7800_8600_png.rf.02cb5de22bac05e3e9bc9a9834ed4b83.jpg: 640x640 4 ships, 20.1ms
# image 257/672 /kaggle/working/dataset/yolo/images/test/P0026_2400_3200_2400_3200_png.rf.13ed30c461b9c0d67a452a5882c2d7ec.jpg: 640x640 1 ship, 21.6ms
# image 258/672 /kaggle/working/dataset/yolo/images/test/P0027_1800_2600_7800_8600_png.rf.8e310d8d7511ec9c57e0ad43703f2313.jpg: 640x640 1 ship, 19.8ms
# image 259/672 /kaggle/working/dataset/yolo/images/test/P0027_1800_2600_8289_9089_png.rf.cb21958fe4c9d2ba499284b0d94ce136.jpg: 640x640 6 ships, 21.4ms
# image 260/672 /kaggle/working/dataset/yolo/images/test/P0027_600_1400_7800_8600_png.rf.a969a8442b8cf0fc99796efdb2cad666.jpg: 640x640 1 ship, 20.0ms
# image 261/672 /kaggle/working/dataset/yolo/images/test/P0028_3000_3800_1800_2600_png.rf.2f7a2d2be5a413140cb79d38ee32f2ae.jpg: 640x640 1 ship, 21.5ms
# image 262/672 /kaggle/working/dataset/yolo/images/test/P0028_3600_4400_3000_3800_png.rf.21da1c24201efddb97741c187f73eb8f.jpg: 640x640 3 ships, 20.3ms
# image 263/672 /kaggle/working/dataset/yolo/images/test/P0028_4800_5600_6600_7400_png.rf.2ac5a8ef4f8c2209183da05a2cad9f48.jpg: 640x640 4 ships, 21.3ms
# image 264/672 /kaggle/working/dataset/yolo/images/test/P0028_5400_6200_7200_8000_png.rf.e65b23925a34d65b3d2b6f4e47e6609c.jpg: 640x640 2 ships, 20.4ms
# image 265/672 /kaggle/working/dataset/yolo/images/test/P0028_5810_6610_1800_2600_png.rf.fcafd2abf3d81c7552cc0242198f914a.jpg: 640x640 1 ship, 20.9ms
# image 266/672 /kaggle/working/dataset/yolo/images/test/P0028_5810_6610_6000_6800_png.rf.a799531ff66a26668142b30acaf0b8f2.jpg: 640x640 4 ships, 20.4ms
# image 267/672 /kaggle/working/dataset/yolo/images/test/P0028_600_1400_7200_8000_png.rf.d614b0004e1345b6c2fe43097f57b610.jpg: 640x640 3 ships, 20.4ms
# image 268/672 /kaggle/working/dataset/yolo/images/test/P0029_1800_2600_3600_4400_png.rf.c52587593c2ea151451a7ed769c90ad1.jpg: 640x640 1 ship, 20.5ms
# image 269/672 /kaggle/working/dataset/yolo/images/test/P0029_3600_4400_3600_4400_png.rf.df6e5871307da5265cf7f180d2f481c6.jpg: 640x640 2 ships, 21.0ms
# image 270/672 /kaggle/working/dataset/yolo/images/test/P0029_4800_5600_6000_6800_png.rf.577fa38f08b369c03710a9fb91775b40.jpg: 640x640 1 ship, 20.5ms
# image 271/672 /kaggle/working/dataset/yolo/images/test/P0029_4800_5600_6600_7400_png.rf.0b5897eb5125e14afaeb7cd51157d369.jpg: 640x640 2 ships, 21.3ms
# image 272/672 /kaggle/working/dataset/yolo/images/test/P0029_5400_6200_5400_6200_png.rf.94daddb6a5b3744661092ad341e1c391.jpg: 640x640 1 ship, 20.8ms
# image 273/672 /kaggle/working/dataset/yolo/images/test/P0030_4200_5000_4200_5000_png.rf.18863acef7dad6dfa5c218ef0871d5b2.jpg: 640x640 4 ships, 21.2ms
# image 274/672 /kaggle/working/dataset/yolo/images/test/P0030_4800_5600_1200_2000_png.rf.e89b2d0007edf1dda7766121524e7bcd.jpg: 640x640 1 ship, 20.6ms
# image 275/672 /kaggle/working/dataset/yolo/images/test/P0030_5400_6200_0_800_png.rf.c64c6473dbd9c4c94a4cc1cdce6363da.jpg: 640x640 1 ship, 20.7ms
# image 276/672 /kaggle/working/dataset/yolo/images/test/P0030_5660_6460_2400_3200_png.rf.e4d79020b05a6e93c876064c5cbc2ca9.jpg: 640x640 1 ship, 20.4ms
# image 277/672 /kaggle/working/dataset/yolo/images/test/P0030_600_1400_7200_8000_png.rf.55359e142b1d8e43efa90ee0296341aa.jpg: 640x640 2 ships, 20.8ms
# image 278/672 /kaggle/working/dataset/yolo/images/test/P0031_1200_2000_4200_5000_png.rf.795b96c91455c8091e9e3024f0263769.jpg: 640x640 2 ships, 20.5ms
# image 279/672 /kaggle/working/dataset/yolo/images/test/P0031_1800_2600_2400_3200_png.rf.4b8f202b7c4592be979ccfcfc1c63d82.jpg: 640x640 1 ship, 20.9ms
# image 280/672 /kaggle/working/dataset/yolo/images/test/P0031_1800_2600_4200_5000_png.rf.76e7d3b60daee3dbeb6f7bfc20c21e0f.jpg: 640x640 2 ships, 20.5ms
# image 281/672 /kaggle/working/dataset/yolo/images/test/P0031_2400_3200_3000_3800_png.rf.d07b23d376d482246c6f7168f8500992.jpg: 640x640 1 ship, 20.9ms
# image 282/672 /kaggle/working/dataset/yolo/images/test/P0031_2400_3200_4200_5000_png.rf.19595185d75bb1968acf8f0fa5ed063d.jpg: 640x640 3 ships, 20.0ms
# image 283/672 /kaggle/working/dataset/yolo/images/test/P0031_3000_3800_3600_4400_png.rf.698966267ab112db9d7a972c2bdfa37b.jpg: 640x640 1 ship, 21.2ms
# image 284/672 /kaggle/working/dataset/yolo/images/test/P0031_4200_5000_0_800_png.rf.089ac38457dae50a142eed0efca597ba.jpg: 640x640 1 ship, 20.4ms
# image 285/672 /kaggle/working/dataset/yolo/images/test/P0031_4800_5600_1200_2000_png.rf.d8988a98d156b11ee45abaccc82077a1.jpg: 640x640 1 ship, 21.6ms
# image 286/672 /kaggle/working/dataset/yolo/images/test/P0031_4800_5600_6600_7400_png.rf.843c651ea2c95acc2939e597e91d0f73.jpg: 640x640 4 ships, 20.0ms
# image 287/672 /kaggle/working/dataset/yolo/images/test/P0031_5160_5960_6000_6800_png.rf.3d4cdb77dca3cc5ce67f693469cc09bd.jpg: 640x640 1 ship, 21.4ms
# image 288/672 /kaggle/working/dataset/yolo/images/test/P0031_600_1400_3600_4400_png.rf.886b1bc3ba72101439501af531f0f5ff.jpg: 640x640 2 ships, 20.1ms
# image 289/672 /kaggle/working/dataset/yolo/images/test/P0032_1800_2600_7200_8000_png.rf.142eebd27d9a7fd697d5c35e2db00e05.jpg: 640x640 1 ship, 21.8ms
# image 290/672 /kaggle/working/dataset/yolo/images/test/P0032_2400_3200_7200_8000_png.rf.830434413f9f0bb8f16ba03a74e4646f.jpg: 640x640 2 ships, 20.4ms
# image 291/672 /kaggle/working/dataset/yolo/images/test/P0032_4560_5360_0_800_png.rf.de8a3311c3582f0bc98a16a7a5b966ef.jpg: 640x640 1 ship, 22.0ms
# image 292/672 /kaggle/working/dataset/yolo/images/test/P0032_4560_5360_600_1400_png.rf.62aa70516c87535e803daff7b89024de.jpg: 640x640 1 ship, 20.4ms
# image 293/672 /kaggle/working/dataset/yolo/images/test/P0032_600_1400_3600_4400_png.rf.36718abba3ddcef3cf0a670330019508.jpg: 640x640 1 ship, 21.6ms
# image 294/672 /kaggle/working/dataset/yolo/images/test/P0032_600_1400_8400_9200_png.rf.f4a079810c758e5725c94781c18dbf9c.jpg: 640x640 10 ships, 20.1ms
# image 295/672 /kaggle/working/dataset/yolo/images/test/P0033_0_800_7200_8000_png.rf.5835f1041fa57b268268eb0c1d1b3773.jpg: 640x640 3 ships, 21.7ms
# image 296/672 /kaggle/working/dataset/yolo/images/test/P0033_1800_2600_3000_3800_png.rf.325f79ab9a936a5e96224607650082dd.jpg: 640x640 1 ship, 20.4ms
# image 297/672 /kaggle/working/dataset/yolo/images/test/P0033_1800_2600_4800_5600_png.rf.48f06b5bec67fae3cafa490416dd1f96.jpg: 640x640 1 ship, 21.3ms
# image 298/672 /kaggle/working/dataset/yolo/images/test/P0033_3600_4400_0_800_png.rf.ab126461c7207aa2d26d7d837a28e0bb.jpg: 640x640 1 ship, 20.8ms
# image 299/672 /kaggle/working/dataset/yolo/images/test/P0033_3600_4400_3600_4400_png.rf.b64d978d1d6a715d4af27e66da14ca92.jpg: 640x640 2 ships, 20.9ms
# image 300/672 /kaggle/working/dataset/yolo/images/test/P0033_4200_5000_6600_7400_png.rf.08d16ec29011d6c7f3df8901d1b74e93.jpg: 640x640 3 ships, 20.9ms
# image 301/672 /kaggle/working/dataset/yolo/images/test/P0033_5260_6060_0_800_png.rf.4fcf1d89ed2a6f0a702ca096321009d5.jpg: 640x640 1 ship, 20.8ms
# image 302/672 /kaggle/working/dataset/yolo/images/test/P0034_1200_2000_8400_9200_png.rf.621c9dbb8c557a246cc1b0bbb7aa4f73.jpg: 640x640 5 ships, 21.2ms
# image 303/672 /kaggle/working/dataset/yolo/images/test/P0034_3600_4400_3600_4400_png.rf.fa170e73792b7d7c04effb68ad84c8e2.jpg: 640x640 1 ship, 20.8ms
# image 304/672 /kaggle/working/dataset/yolo/images/test/P0034_4200_5000_2400_3200_png.rf.414fd3855ddc325c80519a58a7f6d85e.jpg: 640x640 2 ships, 20.4ms
# image 305/672 /kaggle/working/dataset/yolo/images/test/P0034_5160_5960_5400_6200_png.rf.7c6e150d433b69d6091abf99e7ca5997.jpg: 640x640 1 ship, 21.1ms
# image 306/672 /kaggle/working/dataset/yolo/images/test/P0034_5160_5960_6600_7400_png.rf.6dd6e3454d5cf4876f26dcccc92b556e.jpg: 640x640 4 ships, 20.4ms
# image 307/672 /kaggle/working/dataset/yolo/images/test/P0035_1800_2600_8400_9200_png.rf.a166145543575128a66bea5476c1346b.jpg: 640x640 7 ships, 21.5ms
# image 308/672 /kaggle/working/dataset/yolo/images/test/P0035_4200_5000_3000_3800_png.rf.a3a35ef15e182ecac82c8aea342edf0c.jpg: 640x640 2 ships, 20.5ms
# image 309/672 /kaggle/working/dataset/yolo/images/test/P0035_4800_5600_1200_2000_png.rf.5d2019ca04311b24ef5e885b54f4c5ad.jpg: 640x640 2 ships, 20.8ms
# image 310/672 /kaggle/working/dataset/yolo/images/test/P0035_4800_5600_3000_3800_png.rf.6141aa6ff735d183cb476577041070f1.jpg: 640x640 3 ships, 20.5ms
# image 311/672 /kaggle/working/dataset/yolo/images/test/P0035_4800_5600_4200_5000_png.rf.ad4bc334702df1cd6b6d53c5786793bf.jpg: 640x640 2 ships, 20.9ms
# image 312/672 /kaggle/working/dataset/yolo/images/test/P0035_600_1400_9289_10089_png.rf.3cb51fd8a0a083cf7b925a126abad349.jpg: 640x640 2 ships, 20.0ms
# image 313/672 /kaggle/working/dataset/yolo/images/test/P0035_6260_7060_1200_2000_png.rf.fefef46f4b16cfd00bc87203a2240dd2.jpg: 640x640 2 ships, 21.1ms
# image 314/672 /kaggle/working/dataset/yolo/images/test/P0035_6260_7060_600_1400_png.rf.0a0552dac1d8b3adcb623e6e6ae47617.jpg: 640x640 2 ships, 20.1ms
# image 315/672 /kaggle/working/dataset/yolo/images/test/P0035_6260_7060_6600_7400_png.rf.df76c29c7271a4de8f3876f9315fb017.jpg: 640x640 3 ships, 21.9ms
# image 316/672 /kaggle/working/dataset/yolo/images/test/P0036_1800_2600_2400_3200_png.rf.c922e4720bbc33128a46f67669634f95.jpg: 640x640 2 ships, 20.5ms
# image 317/672 /kaggle/working/dataset/yolo/images/test/P0036_3000_3800_5400_6200_png.rf.ad37a179f2c1fdbc8080152920a6eaa2.jpg: 640x640 1 ship, 21.6ms
# image 318/672 /kaggle/working/dataset/yolo/images/test/P0036_3600_4400_3600_4400_png.rf.e06260ab50ab3484076babb7eefabbb4.jpg: 640x640 2 ships, 20.2ms
# image 319/672 /kaggle/working/dataset/yolo/images/test/P0036_4200_5000_6600_7400_png.rf.5f32ee63f4f8deb9237109c9b8981e22.jpg: 640x640 1 ship, 20.3ms
# image 320/672 /kaggle/working/dataset/yolo/images/test/P0036_5160_5960_0_800_png.rf.a5ef9924c5d1a5050d462413359b464a.jpg: 640x640 1 ship, 20.5ms
# image 321/672 /kaggle/working/dataset/yolo/images/test/P0036_5160_5960_2400_3200_png.rf.46958f443e3719d5c8a9d9dbe6238fc7.jpg: 640x640 1 ship, 21.5ms
# image 322/672 /kaggle/working/dataset/yolo/images/test/P0036_5160_5960_600_1400_png.rf.3225940762918dfbb6c037e304ea7c06.jpg: 640x640 1 ship, 20.7ms
# image 323/672 /kaggle/working/dataset/yolo/images/test/P0036_5160_5960_7200_8000_png.rf.6a351940421d5e1bc17aa5dbdda26d97.jpg: 640x640 1 ship, 21.9ms
# image 324/672 /kaggle/working/dataset/yolo/images/test/P0036_600_1400_8400_9200_png.rf.ef749f831ff721d8ce8480270a35abeb.jpg: 640x640 5 ships, 20.8ms
# image 325/672 /kaggle/working/dataset/yolo/images/test/P0037_1200_2000_5400_6200_png.rf.ea402f429a5bebe076b55eddf6bb6f53.jpg: 640x640 1 ship, 21.7ms
# image 326/672 /kaggle/working/dataset/yolo/images/test/P0037_1800_2600_2400_3200_png.rf.c0ccf9ed101664772c263b807676cfbb.jpg: 640x640 1 ship, 20.8ms
# image 327/672 /kaggle/working/dataset/yolo/images/test/P0037_1800_2600_3600_4400_png.rf.dd49f9c3fb9d3cc84d1ab2e9648625ec.jpg: 640x640 3 ships, 21.7ms
# image 328/672 /kaggle/working/dataset/yolo/images/test/P0037_2400_3200_3000_3800_png.rf.673efd1457af4cf95b88c5c1d56b0c47.jpg: 640x640 1 ship, 20.4ms
# image 329/672 /kaggle/working/dataset/yolo/images/test/P0037_4200_5000_6000_6800_png.rf.992d8d3520338faf9966232c10986f2c.jpg: 640x640 3 ships, 21.1ms
# image 330/672 /kaggle/working/dataset/yolo/images/test/P0037_600_1400_3600_4400_png.rf.777073fa2b89d794ee189b36e7dc35ba.jpg: 640x640 1 ship, 20.4ms
# image 331/672 /kaggle/working/dataset/yolo/images/test/P0037_600_1400_4800_5600_png.rf.878c5a17c2461f12e70f7c61e37f7925.jpg: 640x640 2 ships, 21.6ms
# image 332/672 /kaggle/working/dataset/yolo/images/test/P0038_0_800_9189_9989_png.rf.9c215d77c325dbceb30b480da26853b6.jpg: 640x640 4 ships, 19.8ms
# image 333/672 /kaggle/working/dataset/yolo/images/test/P0038_1800_2600_0_800_png.rf.ba1b6b38f8aa7dfa1f6a72d6e6c23b56.jpg: 640x640 1 ship, 21.6ms
# image 334/672 /kaggle/working/dataset/yolo/images/test/P0038_3600_4400_4800_5600_png.rf.98c534897fae952e5eded09cdc0d37c5.jpg: 640x640 1 ship, 20.1ms
# image 335/672 /kaggle/working/dataset/yolo/images/test/P0039_0_800_8400_9200_png.rf.6c57bf484c06616009a9b34b078ee235.jpg: 640x640 2 ships, 21.8ms
# ...
# image 567/672 /kaggle/working/dataset/yolo/images/test/P0098_600_1400_4200_5000_png.rf.40f83a8b509613c6833923de4f3c2faa.jpg: 640x640 4 ships, 20.8ms
# image 568/672 /kaggle/working/dataset/yolo/images/test/P0101_1500_2300_2400_3200_png.rf.71669121d760169be8e9afe6d8cfb62f.jpg: 640x640 4 ships, 21.7ms
# image 569/672 /kaggle/working/dataset/yolo/images/test/P0101_1500_2300_600_1400_png.rf.b1a271106e4576ce46778e2315c37828.jpg: 640x640 1 ship, 21.3ms
# image 570/672 /kaggle/working/dataset/yolo/images/test/P0102_0_800_1800_2600_png.rf.840f496d50b6aac373e4f683f79b0b6d.jpg: 640x640 3 ships, 20.2ms
# image 571/672 /kaggle/working/dataset/yolo/images/test/P0102_1200_2000_1200_2000_png.rf.833538deead26866dece217934586af8.jpg: 640x640 2 ships, 21.9ms
# image 572/672 /kaggle/working/dataset/yolo/images/test/P0102_1200_2000_1800_2600_png.rf.572945798055ef0aa5bb00eb12aca241.jpg: 640x640 1 ship, 20.0ms
# image 573/672 /kaggle/working/dataset/yolo/images/test/P0102_1800_2600_3000_3800_png.rf.f99c163b4e9499c2d29eb077d2f9f2d6.jpg: 640x640 7 ships, 22.4ms
# image 574/672 /kaggle/working/dataset/yolo/images/test/P0103_0_800_1800_2600_png.rf.20a5adf6bd818fdeb7bdd43a9d2212a7.jpg: 640x640 3 ships, 20.4ms
# image 575/672 /kaggle/working/dataset/yolo/images/test/P0103_1700_2500_0_800_png.rf.9e50976107e5259040db9517f43b6dd1.jpg: 640x640 1 ship, 20.5ms
# image 576/672 /kaggle/working/dataset/yolo/images/test/P0104_0_800_2400_3200_png.rf.dba22e43fc2cc7976cc71b67f3759437.jpg: 640x640 2 ships, 21.2ms
# image 577/672 /kaggle/working/dataset/yolo/images/test/P0104_2200_3000_2400_3200_png.rf.de6222b69b1543de56ef70807db1c2f3.jpg: 640x640 1 ship, 20.4ms
# image 578/672 /kaggle/working/dataset/yolo/images/test/P0105_1200_2000_3600_4400_png.rf.71ce8713878a09aa84451a5cd946a1e1.jpg: 640x640 1 ship, 21.9ms
# image 579/672 /kaggle/working/dataset/yolo/images/test/P0105_1800_2600_11400_12200_png.rf.c7bcbfd51a5442d30d7235acc82078ae.jpg: 640x640 1 ship, 20.2ms
# image 580/672 /kaggle/working/dataset/yolo/images/test/P0105_1800_2600_8400_9200_png.rf.9e575b2a01bb32663105cdec48ca0f83.jpg: 640x640 1 ship, 21.9ms
# image 581/672 /kaggle/working/dataset/yolo/images/test/P0105_2400_3200_11400_12200_png.rf.867a12728111fb0eda97b2ca925f3868.jpg: 640x640 1 ship, 20.1ms
# image 582/672 /kaggle/working/dataset/yolo/images/test/P0105_2400_3200_12000_12800_png.rf.9f4774a0fe46e6b8b63ab3759383430c.jpg: 640x640 2 ships, 22.3ms
# image 583/672 /kaggle/working/dataset/yolo/images/test/P0105_2400_3200_16800_17600_png.rf.6940552cc1304f3f7951cfdb0da9c88f.jpg: 640x640 10 ships, 20.4ms
# image 584/672 /kaggle/working/dataset/yolo/images/test/P0105_2400_3200_19200_20000_png.rf.fa5acbcd7ab31bdf9f1f17cb8ba71a2a.jpg: 640x640 5 ships, 22.5ms
# image 585/672 /kaggle/working/dataset/yolo/images/test/P0105_2400_3200_19800_20600_png.rf.a49541317661367f4e66a2372f0e88db.jpg: 640x640 2 ships, 20.5ms
# image 586/672 /kaggle/working/dataset/yolo/images/test/P0105_3000_3800_15600_16400_png.rf.5f5b9afafb8c818ec8c244e333c7a344.jpg: 640x640 3 ships, 21.6ms
# image 587/672 /kaggle/working/dataset/yolo/images/test/P0105_3000_3800_16200_17000_png.rf.4478b51a565a96e7ff68ae4de7810378.jpg: 640x640 8 ships, 20.4ms
# image 588/672 /kaggle/working/dataset/yolo/images/test/P0105_3000_3800_18000_18800_png.rf.a4d8db2d24658b88dea7dacfb1ca6970.jpg: 640x640 2 ships, 21.7ms
# image 589/672 /kaggle/working/dataset/yolo/images/test/P0105_3600_4400_15600_16400_png.rf.2b29880f8e2256d0d65775194a7529f4.jpg: 640x640 30 ships, 20.9ms
# image 590/672 /kaggle/working/dataset/yolo/images/test/P0105_600_1400_16200_17000_png.rf.54fb87e4fc4b424b12fc506496aeefef.jpg: 640x640 1 ship, 20.1ms
# image 591/672 /kaggle/working/dataset/yolo/images/test/P0106_3600_4400_18000_18800_png.rf.9913766391264356a890be5848fb5e54.jpg: 640x640 1 ship, 21.1ms
# image 592/672 /kaggle/working/dataset/yolo/images/test/P0107_2400_3200_1800_2600_png.rf.25220eec6dccc17e8c3264075d3f9412.jpg: 640x640 1 ship, 19.5ms
# image 593/672 /kaggle/working/dataset/yolo/images/test/P0108_0_800_7200_8000_png.rf.319ced6237d8090f76097189820dd95c.jpg: 640x640 1 ship, 21.6ms
# image 594/672 /kaggle/working/dataset/yolo/images/test/P0108_0_800_8400_9200_png.rf.99eb5641567a90529c0839993ab60dc4.jpg: 640x640 2 ships, 20.7ms
# image 595/672 /kaggle/working/dataset/yolo/images/test/P0108_1200_2000_4800_5600_png.rf.ffd350cc59351cd10997c64570719dde.jpg: 640x640 3 ships, 22.8ms
# image 596/672 /kaggle/working/dataset/yolo/images/test/P0108_3000_3800_5400_6200_png.rf.48c8bd6598821809c26307358b86567f.jpg: 640x640 1 ship, 20.7ms
# image 597/672 /kaggle/working/dataset/yolo/images/test/P0108_3000_3800_6000_6800_png.rf.66f0d121f850704179a66805e7a33850.jpg: 640x640 1 ship, 22.7ms
# image 598/672 /kaggle/working/dataset/yolo/images/test/P0108_600_1400_4800_5600_png.rf.68f335b511bb43d9009a3c6af075c9d1.jpg: 640x640 4 ships, 20.9ms
# image 599/672 /kaggle/working/dataset/yolo/images/test/P0109_3000_3800_8400_9200_png.rf.3f0a550aad77c6a12e5d66b8fde089f9.jpg: 640x640 13 ships, 21.7ms
# image 600/672 /kaggle/working/dataset/yolo/images/test/P0109_4200_5000_10200_11000_png.rf.d6668b5996d2919b17d0d92835bb2379.jpg: 640x640 16 ships, 20.4ms
# image 601/672 /kaggle/working/dataset/yolo/images/test/P0110_6200_7000_6000_6800_png.rf.be9c3cecebabc5071d1707f8a810151c.jpg: 640x640 4 ships, 19.7ms
# image 602/672 /kaggle/working/dataset/yolo/images/test/P0111_4800_5600_8400_9200_png.rf.8ee0682f1595221da1ae3f317a077301.jpg: 640x640 13 ships, 21.7ms
# image 603/672 /kaggle/working/dataset/yolo/images/test/P0111_6000_6800_10200_11000_png.rf.6b66b71500d5b8b1b03598029cb41e2a.jpg: 640x640 13 ships, 20.1ms
# image 604/672 /kaggle/working/dataset/yolo/images/test/P0112_2400_3200_2400_3200_png.rf.b01403720d8f6a6fe542bf6d1bf228ee.jpg: 640x640 1 ship, 20.6ms
# image 605/672 /kaggle/working/dataset/yolo/images/test/P0112_2400_3200_600_1400_png.rf.029660bfe259623ba3c824bf3d03ef4b.jpg: 640x640 1 ship, 20.8ms
# image 606/672 /kaggle/working/dataset/yolo/images/test/P0112_3000_3800_4200_5000_png.rf.12aaed5997854576955b33187e8572ab.jpg: 640x640 2 ships, 21.4ms
# image 607/672 /kaggle/working/dataset/yolo/images/test/P0112_3600_4400_7200_8000_png.rf.4beb2a142d4e4d12902a2efe132aaf37.jpg: 640x640 25 ships, 21.3ms
# image 608/672 /kaggle/working/dataset/yolo/images/test/P0112_3600_4400_7800_8600_png.rf.b25bdfc76de6a98561f1b4ef8139413c.jpg: 640x640 8 ships, 20.3ms
# image 609/672 /kaggle/working/dataset/yolo/images/test/P0113_1200_2000_11400_12200_png.rf.dd297292ee8acf15c857281fd55fbb54.jpg: 640x640 1 ship, 22.1ms
# image 610/672 /kaggle/working/dataset/yolo/images/test/P0113_1800_2600_10200_11000_png.rf.7a1926e284ab272e4a627efc87fadb55.jpg: 640x640 1 ship, 20.4ms
# image 611/672 /kaggle/working/dataset/yolo/images/test/P0113_2400_3200_8400_9200_png.rf.0287b319fe8f6a2a61453def0225c2d1.jpg: 640x640 1 ship, 22.8ms
# image 612/672 /kaggle/working/dataset/yolo/images/test/P0113_3600_4400_600_1400_png.rf.b172b3301aa12dd027a920ac76076273.jpg: 640x640 (no detections), 20.9ms
# image 613/672 /kaggle/working/dataset/yolo/images/test/P0113_3600_4400_6600_7400_png.rf.7faf472a0a3cc3383eb93362ff0137c2.jpg: 640x640 2 ships, 22.2ms
# image 614/672 /kaggle/working/dataset/yolo/images/test/P0113_4200_5000_9600_10400_png.rf.c94166482b8b78a3c18326fc7c629c96.jpg: 640x640 2 ships, 20.8ms
# image 615/672 /kaggle/working/dataset/yolo/images/test/P0113_600_1400_10200_11000_png.rf.a900923aa6447cca1567e0de30b65d47.jpg: 640x640 1 ship, 22.4ms
# image 616/672 /kaggle/working/dataset/yolo/images/test/P0114_1200_2000_7800_8600_png.rf.b345c5e27ea9356c8bcc54853b7d748a.jpg: 640x640 4 ships, 20.5ms
# image 617/672 /kaggle/working/dataset/yolo/images/test/P0114_2400_3200_3000_3800_png.rf.9dc9107ad7075446107d390911f36414.jpg: 640x640 2 ships, 22.0ms
# image 618/672 /kaggle/working/dataset/yolo/images/test/P0114_2400_3200_4800_5600_png.rf.dd7131e562031b8faa1fa988c4b4ca20.jpg: 640x640 4 ships, 20.7ms
# image 619/672 /kaggle/working/dataset/yolo/images/test/P0114_3600_4400_1200_2000_png.rf.c68374e9ae1806f28bd7c29e31f27055.jpg: 640x640 3 ships, 21.9ms
# image 620/672 /kaggle/working/dataset/yolo/images/test/P0114_600_1400_1200_2000_png.rf.dfb277e7509d829b5da2cabfaaebd74a.jpg: 640x640 1 ship, 20.8ms
# image 621/672 /kaggle/working/dataset/yolo/images/test/P0115_4200_5000_9800_10600_png.rf.c9a192467ca17d776fb64ea2eaf4029d.jpg: 640x640 17 ships, 21.8ms
# image 622/672 /kaggle/working/dataset/yolo/images/test/P0116_3600_4400_8400_9200_png.rf.c339885e8f20e886980b8919250c4d32.jpg: 640x640 2 ships, 21.1ms
# image 623/672 /kaggle/working/dataset/yolo/images/test/P0118_0_800_2400_3200_png.rf.131c923e81374764a9bc65148b45349e.jpg: 640x640 2 ships, 20.0ms
# image 624/672 /kaggle/working/dataset/yolo/images/test/P0118_1200_2000_1200_2000_png.rf.cefd1b859551fcf32fb79d8a118fe626.jpg: 640x640 1 ship, 21.6ms
# image 625/672 /kaggle/working/dataset/yolo/images/test/P0118_1200_2000_1800_2600_png.rf.a52a643b0174ce7e75aa7801d1cc04d8.jpg: 640x640 1 ship, 20.7ms
# image 626/672 /kaggle/working/dataset/yolo/images/test/P0118_1200_2000_6000_6800_png.rf.1432aa7d6c26160a207c9e2c5f891031.jpg: 640x640 7 ships, 22.4ms
# image 627/672 /kaggle/working/dataset/yolo/images/test/P0118_1800_2600_4200_5000_png.rf.4fbe35946c6d1f6df07d207ffab0bef5.jpg: 640x640 3 ships, 20.4ms
# image 628/672 /kaggle/working/dataset/yolo/images/test/P0118_600_1400_2400_3200_png.rf.55220a89e7a9c287dced78aff5627610.jpg: 640x640 1 ship, 22.5ms
# image 629/672 /kaggle/working/dataset/yolo/images/test/P0118_600_1400_5400_6200_png.rf.7f0c8525a11d1d77dddcb00d40ef868e.jpg: 640x640 5 ships, 20.4ms
# image 630/672 /kaggle/working/dataset/yolo/images/test/P0121_0_800_4200_5000_png.rf.6f113c08ca85a79ca4547fc952ff854e.jpg: 640x640 1 ship, 22.2ms
# image 631/672 /kaggle/working/dataset/yolo/images/test/P0121_1800_2600_4200_5000_png.rf.c679b4a8709270cd44cac153403f71b5.jpg: 640x640 1 ship, 20.5ms
# image 632/672 /kaggle/working/dataset/yolo/images/test/P0121_3000_3800_0_800_png.rf.0f815d47163da0e6763014eca12b662b.jpg: 640x640 1 ship, 21.1ms
# image 633/672 /kaggle/working/dataset/yolo/images/test/P0121_3200_4000_1200_2000_png.rf.389637dae3c164a45ef764b22a2e0496.jpg: 640x640 7 ships, 21.3ms
# image 634/672 /kaggle/working/dataset/yolo/images/test/P0121_600_1400_5400_6200_png.rf.54714add33b520af567a011a2449d072.jpg: 640x640 2 ships, 21.3ms
# image 635/672 /kaggle/working/dataset/yolo/images/test/P0122_1200_2000_2400_3200_png.rf.0f37bc3d309b333d1fb983f7f658dfcb.jpg: 640x640 (no detections), 21.7ms
# image 636/672 /kaggle/working/dataset/yolo/images/test/P0123_5400_6200_5400_6200_png.rf.f8d58dc040c74e9b9c9b9a937f40283e.jpg: 640x640 1 ship, 21.0ms
# image 637/672 /kaggle/working/dataset/yolo/images/test/P0124_4200_5000_6600_7400_png.rf.adda273d585974abe5c392e354c27e9e.jpg: 640x640 (no detections), 21.3ms
# image 638/672 /kaggle/working/dataset/yolo/images/test/P0126_3600_4400_10200_11000_png.rf.f642bfccf88a826262dafa624f47a266.jpg: 640x640 (no detections), 21.1ms
# image 639/672 /kaggle/working/dataset/yolo/images/test/P0126_5400_6200_6600_7400_png.rf.9355fe905f7bcb47c1842a65b122709f.jpg: 640x640 1 ship, 20.6ms
# image 640/672 /kaggle/working/dataset/yolo/images/test/P0126_6000_6800_6600_7400_png.rf.53b9c3ef05957609bd6669c16c2caa89.jpg: 640x640 2 ships, 19.6ms
# image 641/672 /kaggle/working/dataset/yolo/images/test/P0126_7800_8600_4200_5000_png.rf.517b160cc40baca90f0b8301f9466367.jpg: 640x640 1 ship, 20.9ms
# image 642/672 /kaggle/working/dataset/yolo/images/test/P0127_1200_2000_15000_15800_png.rf.f06c0d5f983b3b4c9b58176aa765eda9.jpg: 640x640 (no detections), 20.3ms
# image 643/672 /kaggle/working/dataset/yolo/images/test/P0127_3000_3800_9000_9800_png.rf.b18742fcb81e74f4b2cef91cc5375926.jpg: 640x640 (no detections), 21.5ms
# image 644/672 /kaggle/working/dataset/yolo/images/test/P0127_3600_4400_2400_3200_png.rf.420edeed1ea6222d96a88593bd802bb9.jpg: 640x640 1 ship, 20.8ms
# image 645/672 /kaggle/working/dataset/yolo/images/test/P0128_4800_5600_4800_5600_png.rf.6f50639c407074d4c42b927a81edcc79.jpg: 640x640 3 ships, 22.4ms
# image 646/672 /kaggle/working/dataset/yolo/images/test/P0128_5400_6200_7200_8000_png.rf.ae49b1a2900b2d312441269fdfb749b8.jpg: 640x640 (no detections), 21.2ms
# image 647/672 /kaggle/working/dataset/yolo/images/test/P0129_6000_6800_2400_3200_png.rf.44cb6554bea2fff7ab74c07b061bcab6.jpg: 640x640 2 ships, 21.6ms
# image 648/672 /kaggle/working/dataset/yolo/images/test/P0129_6600_7400_3000_3800_png.rf.fae629d4da46d7c25e4ff46ff02d5427.jpg: 640x640 (no detections), 20.9ms
# image 649/672 /kaggle/working/dataset/yolo/images/test/P0131_13800_14600_9600_10400_png.rf.b3ee549c9a81460b22a73249e2d3522b.jpg: 640x640 (no detections), 21.7ms
# image 650/672 /kaggle/working/dataset/yolo/images/test/P0131_7800_8600_1800_2600_png.rf.da4e01c72a08c0743980b3ff18e94551.jpg: 640x640 (no detections), 20.8ms
# image 651/672 /kaggle/working/dataset/yolo/images/test/P0132_1200_2000_9600_10400_png.rf.06c692c12f113e506f4ef94618a66892.jpg: 640x640 1 ship, 21.9ms
# image 652/672 /kaggle/working/dataset/yolo/images/test/P0132_1200_2000_9926_10726_png.rf.347f90bece44d3d68e04f9f580c8572a.jpg: 640x640 1 ship, 21.1ms
# image 653/672 /kaggle/working/dataset/yolo/images/test/P0133_1800_2600_0_800_png.rf.5d9160e8e0f675afb2482a61bd2fc0eb.jpg: 640x640 11 ships, 22.1ms
# image 654/672 /kaggle/working/dataset/yolo/images/test/P0133_4200_5000_4200_5000_png.rf.18b0618f7c460f88a705d0a48e6b3121.jpg: 640x640 1 ship, 21.2ms
# image 655/672 /kaggle/working/dataset/yolo/images/test/P0133_600_1400_0_800_png.rf.788ab7dd9934c7293ab7a18ad87c5210.jpg: 640x640 7 ships, 21.2ms
# image 656/672 /kaggle/working/dataset/yolo/images/test/P0134_6000_6800_5400_6200_png.rf.f2c856f6cd40ee4528683b3f9060191d.jpg: 640x640 (no detections), 21.2ms
# image 657/672 /kaggle/working/dataset/yolo/images/test/P0134_6000_6800_6000_6800_png.rf.48870bce7a6ef7664ccb301282497025.jpg: 640x640 7 ships, 21.1ms
# image 658/672 /kaggle/working/dataset/yolo/images/test/P0135_1200_2000_4200_5000_png.rf.ba1c8ffe00259e485573959110e1b1d9.jpg: 640x640 8 ships, 20.9ms
# image 659/672 /kaggle/working/dataset/yolo/images/test/P0135_1200_2000_6600_7400_png.rf.82e1015b173dd5d05616ab9c2dd1b3f0.jpg: 640x640 6 ships, 21.5ms
# image 660/672 /kaggle/working/dataset/yolo/images/test/P0135_3000_3800_6600_7400_png.rf.8bc9ecc034b8215e90d71c6839918da5.jpg: 640x640 1 ship, 21.2ms
# image 661/672 /kaggle/working/dataset/yolo/images/test/P0135_3600_4400_8400_9200_png.rf.2728d6346fcce01564da8bbaa337f90b.jpg: 640x640 1 ship, 20.8ms
# image 662/672 /kaggle/working/dataset/yolo/images/test/P0135_600_1400_6000_6800_png.rf.11667aa2c5f5a92e09001da820862da8.jpg: 640x640 19 ships, 21.6ms
# image 663/672 /kaggle/working/dataset/yolo/images/test/P0135_600_1400_9600_10400_png.rf.3d376eeef6f6e0aa357efe94af6f89a1.jpg: 640x640 1 ship, 20.9ms
# image 664/672 /kaggle/working/dataset/yolo/images/test/P0137_18_png.rf.83d59122061f48e6f9ec0c436576e0b0.jpg: 640x640 1 ship, 21.6ms
# image 665/672 /kaggle/working/dataset/yolo/images/test/P0137_23_png.rf.bb87ed793cc46b5fad9305728da837dd.jpg: 640x640 2 ships, 19.9ms
# image 666/672 /kaggle/working/dataset/yolo/images/test/P0137_31_png.rf.9ae8a6b7976110b77d23ef46a92f88fb.jpg: 640x640 1 ship, 22.2ms
# image 667/672 /kaggle/working/dataset/yolo/images/test/P0137_44_png.rf.8512e519cb570878fc1476495fb785ad.jpg: 640x640 1 ship, 20.5ms
# image 668/672 /kaggle/working/dataset/yolo/images/test/P0137_70_png.rf.53e247262f0e7afe74cec72d78e4b475.jpg: 640x640 1 ship, 22.7ms
# image 669/672 /kaggle/working/dataset/yolo/images/test/P0137_77_png.rf.f5255f1ea26ec591741520bdb5d8779c.jpg: 640x640 1 ship, 21.0ms
# image 670/672 /kaggle/working/dataset/yolo/images/test/P0137_93_png.rf.b8d15c0bdbff4d30e875ded1aa9f1d7d.jpg: 640x640 1 ship, 22.5ms
# image 671/672 /kaggle/working/dataset/yolo/images/test/P0137_96_png.rf.504d18219f3509a408f0930f32c6e2e1.jpg: 640x640 1 ship, 20.3ms
# image 672/672 /kaggle/working/dataset/yolo/images/test/P0137_98_png.rf.df0a2ae317540fe3ef41ff26d8bdf02e.jpg: 640x640 1 ship, 21.8ms
# Speed: 2.4ms preprocess, 21.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /kaggle/working/runs/detect/predict5

# %%
import matplotlib.pyplot as plt

# Number of images per row
images_per_row = 2
num_images = 6  # total images to display (can be less than len(results))

# Calculate number of rows needed
rows = (num_images + images_per_row - 1) // images_per_row

plt.figure(figsize=(images_per_row * 5, rows * 5))

for i in range(num_images):
    pred_img = results[i].plot()  # image with boxes drawn
    
    plt.subplot(rows, images_per_row, i + 1)
    plt.imshow(pred_img)
    plt.axis('off')
    plt.title(f"Image {i+1}")

plt.tight_layout()
plt.show()

# %%
import shutil

shutil.make_archive("/kaggle/working/runs_v2", 'zip', "/kaggle/working/runs")
# Out:
# '/kaggle/working/runs_v2.zip'
